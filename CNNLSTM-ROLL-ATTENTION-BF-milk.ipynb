# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv3D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer,InputSpec
from keras.layers import Input,Permute
from keras.layers import ConvLSTM2D
from keras.models import Model
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

K.set_image_dim_ordering("th")

class CylindricalPadLSTMCNN(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadLSTMCNN, self).__init__(**kwargs)
        self.n = n
        self.m = m
        assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadLSTMCNN, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,:,testElement.shape[4]-self.n:testElement.shape[4]]
        result=tf.concat([testElement,firstColumns], axis=4)
        result=tf.concat([lastColumns,result], axis=4)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,:,0:self.m,:]
            
            y = tf.fill(tf.shape(firstRows), 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=3)
            result=tf.concat([result,y], axis=3)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadLSTMCNN, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

print("CylindricalPad class layer defined")

def attention_3d_block(inputs,timesteps):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    time_steps=timesteps
    print("input shape ",inputs.shape)
    print(input_dim)
    #print(time_steps)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    
    a_probs=(inputs)
    
    #a_probs = Permute((2, 1))(inputs)
    #a_probs = K.transpose(inputs,(0,2,1,3,4))
    #a_probs = K.permute_dimensions(inputs,(0,2,1,3,4))
    
    print("after permute a_probs shape ",a_probs.shape)
    a_probs=CylindricalPadLSTMCNN(m=0,n=1)(a_probs)
    a_probs = Conv3D(time_steps,(1,1,3),strides=1,padding='valid',activation='softmax')(a_probs)
    print("after conv a_probs shape ",a_probs.shape)
    
    #a = Permute((2, 1))(inputs)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #a = Reshape((-1,input_dim, time_steps))(a) # this line is not useful. It's just to know which dimension is what.
    #a = Conv2D(100,3,padding='same')(a)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #a = concatenate(neurVec)
    #a_probs = Dense(100, activation='softmax')(a)
    #a = Reshape((input_dim, time_steps))(a)
    #a_probs =  K.permute_dimensions(a_probs,(0,2,1,3,4)) #, name='attention_vec ' % (depth)
    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul= Multiply()([inputs, a_probs]) #name='attention_mul'
    return output_attention_mul


class CNNLSTMROLL:
    @staticmethod
    def build(timeSteps,rows, cols,classes):
        
        inputNet = Input(shape=(timeSteps,1,rows, cols)) #batch_shape=(20, 7, 5) 
        cyPad1=CylindricalPadLSTMCNN(m=0,n=3)(inputNet)
        convlstm2d=ConvLSTM2D(20, kernel_size=(2,7), padding="valid", dropout=0.2, recurrent_dropout=0.1,return_sequences=True)(cyPad1)
        #Bidirectional(              ,merge_mode='concat')
        #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
        #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
        attention_mul = attention_3d_block(convlstm2d,timeSteps)
        cyPad2=CylindricalPadLSTMCNN(m=0,n=3)(attention_mul)
        convlstm2d=ConvLSTM2D(20, kernel_size=(2,7), padding="valid", dropout=0.2, recurrent_dropout=0.1,return_sequences=False)(cyPad2)
        flat = Flatten()(convlstm2d)
        
        #flat=Flatten()(convlstm2d)

        classificationLayer=Dense(classes)(flat)
        classificationLayer=Activation("softmax")(classificationLayer)
        
        #classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# CylindricalPad class layer defined

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_validation import train_test_split

def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-size168-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size168-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.as_matrix().astype(np.float32),dfout.as_matrix().astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,168,8))
total_inputs = np.reshape(total_inputs, (-1,7,24,8))

print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (2868, 7, 24, 8)
# 2868
# ############# train shapes #############
# (2295, 7, 24, 8)
# (2295, 1)
# ############# test shapes #############
# (573, 7, 24, 8)
# (573, 1)
# /home/rjpg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs[:,:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:,:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = CNNLSTMROLL.build(timeSteps=7,rows=24, cols=8,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (573, 5)
# input shape  (?, ?, 20, 23, 8)
# 20
# after permute a_probs shape  (?, ?, 20, 23, 8)
# after conv a_probs shape  (?, 7, 20, 23, 8)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 7, 1, 24, 8)  0
# __________________________________________________________________________________________________
# cylindrical_pad_lstmcnn_1 (Cyli (None, 7, 1, 24, 14) 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)     (None, 7, 20, 23, 8) 23600       cylindrical_pad_lstmcnn_1[0][0]
# __________________________________________________________________________________________________
# cylindrical_pad_lstmcnn_2 (Cyli (None, 7, 20, 23, 10 0           conv_lst_m2d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 7, 20, 23, 8) 154         cylindrical_pad_lstmcnn_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 7, 20, 23, 8) 0           conv_lst_m2d_1[0][0]
#                                                                  conv3d_1[0][0]
# __________________________________________________________________________________________________
# cylindrical_pad_lstmcnn_3 (Cyli (None, 7, 20, 23, 14 0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)     (None, 20, 22, 8)    44880       cylindrical_pad_lstmcnn_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3520)         0           conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            17605       flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 5)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 86,239
# Trainable params: 86,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('CNNLSTM-ROLL-ATTENTION-BF-energie.h5', monitor='val_acc', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[best_checkpoint])
# Out:
# Train on 2295 samples, validate on 573 samples
# Epoch 1/100
# 2295/2295 [==============================] - 12s 5ms/step - loss: 1.5837 - acc: 0.2675 - val_loss: 1.5656 - val_acc: 0.2356
#
# Epoch 00001: val_acc improved from -inf to 0.23560, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 2/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.5158 - acc: 0.3224 - val_loss: 1.5218 - val_acc: 0.2653
#
# Epoch 00002: val_acc improved from 0.23560 to 0.26527, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 3/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4633 - acc: 0.3569 - val_loss: 1.4814 - val_acc: 0.3054
#
# Epoch 00003: val_acc improved from 0.26527 to 0.30541, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 4/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4625 - acc: 0.3451 - val_loss: 1.4715 - val_acc: 0.3054
#
# Epoch 00004: val_acc improved from 0.30541 to 0.30541, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 5/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.4437 - acc: 0.3712 - val_loss: 1.4523 - val_acc: 0.3438
#
# Epoch 00005: val_acc improved from 0.30541 to 0.34380, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 6/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.4311 - acc: 0.3830 - val_loss: 1.5063 - val_acc: 0.2845
#
# Epoch 00006: val_acc did not improve from 0.34380
# Epoch 7/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.4313 - acc: 0.3730 - val_loss: 1.4602 - val_acc: 0.3508
#
# Epoch 00007: val_acc improved from 0.34380 to 0.35079, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 8/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.4208 - acc: 0.3808 - val_loss: 1.4567 - val_acc: 0.3508
#
# Epoch 00008: val_acc did not improve from 0.35079
# Epoch 9/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4205 - acc: 0.3791 - val_loss: 1.4804 - val_acc: 0.3246
#
# Epoch 00009: val_acc did not improve from 0.35079
# Epoch 10/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4165 - acc: 0.3778 - val_loss: 1.4664 - val_acc: 0.3264
#
# Epoch 00010: val_acc did not improve from 0.35079
# Epoch 11/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4091 - acc: 0.3895 - val_loss: 1.4164 - val_acc: 0.3839
#
# Epoch 00011: val_acc improved from 0.35079 to 0.38394, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 12/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4162 - acc: 0.3861 - val_loss: 1.4293 - val_acc: 0.3578
#
# Epoch 00012: val_acc did not improve from 0.38394
# Epoch 13/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4017 - acc: 0.3852 - val_loss: 1.4040 - val_acc: 0.3735
#
# Epoch 00013: val_acc did not improve from 0.38394
# Epoch 14/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.3837 - acc: 0.4009 - val_loss: 1.4741 - val_acc: 0.3525
#
# Epoch 00014: val_acc did not improve from 0.38394
# Epoch 15/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.3770 - acc: 0.4022 - val_loss: 1.4114 - val_acc: 0.3717
#
# Epoch 00015: val_acc did not improve from 0.38394
# Epoch 16/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.3765 - acc: 0.3965 - val_loss: 1.4339 - val_acc: 0.3560
#
# Epoch 00016: val_acc did not improve from 0.38394
# Epoch 17/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.3684 - acc: 0.4070 - val_loss: 1.3940 - val_acc: 0.3979
#
# Epoch 00017: val_acc improved from 0.38394 to 0.39791, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 18/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3579 - acc: 0.4100 - val_loss: 1.4202 - val_acc: 0.3595
#
# Epoch 00018: val_acc did not improve from 0.39791
# Epoch 19/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.3727 - acc: 0.4026 - val_loss: 1.4314 - val_acc: 0.3752
#
# Epoch 00019: val_acc did not improve from 0.39791
# Epoch 20/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.3580 - acc: 0.4131 - val_loss: 1.3864 - val_acc: 0.3909
#
# Epoch 00020: val_acc did not improve from 0.39791
# Epoch 21/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3423 - acc: 0.4279 - val_loss: 1.3799 - val_acc: 0.3927
#
# Epoch 00021: val_acc did not improve from 0.39791
# Epoch 22/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3462 - acc: 0.4144 - val_loss: 1.3920 - val_acc: 0.3874
#
# Epoch 00022: val_acc did not improve from 0.39791
# Epoch 23/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3399 - acc: 0.4105 - val_loss: 1.3809 - val_acc: 0.3717
#
# Epoch 00023: val_acc did not improve from 0.39791
# Epoch 24/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3336 - acc: 0.4139 - val_loss: 1.3986 - val_acc: 0.3700
#
# Epoch 00024: val_acc did not improve from 0.39791
# Epoch 25/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3290 - acc: 0.4279 - val_loss: 1.4219 - val_acc: 0.3682
#
# Epoch 00025: val_acc did not improve from 0.39791
# Epoch 26/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3400 - acc: 0.4200 - val_loss: 1.3715 - val_acc: 0.3857
#
# Epoch 00026: val_acc did not improve from 0.39791
# Epoch 27/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3216 - acc: 0.4322 - val_loss: 1.3914 - val_acc: 0.3822
#
# Epoch 00027: val_acc did not improve from 0.39791
# Epoch 28/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3241 - acc: 0.4309 - val_loss: 1.3717 - val_acc: 0.3979
#
# Epoch 00028: val_acc did not improve from 0.39791
# Epoch 29/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3290 - acc: 0.4270 - val_loss: 1.3636 - val_acc: 0.3997
#
# Epoch 00029: val_acc improved from 0.39791 to 0.39965, saving model to CNNLSTM-ROLL-ATTENTION-BF-energie.h5
# Epoch 30/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3189 - acc: 0.4231 - val_loss: 1.3854 - val_acc: 0.3630
#
# Epoch 00030: val_acc did not improve from 0.39965
# Epoch 31/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3130 - acc: 0.4275 - val_loss: 1.3710 - val_acc: 0.3874
#
# Epoch 00031: val_acc did not improve from 0.39965
# Epoch 32/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3123 - acc: 0.4340 - val_loss: 1.3870 - val_acc: 0.3857
#
# Epoch 00032: val_acc did not improve from 0.39965
# Epoch 33/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3173 - acc: 0.4261 - val_loss: 1.3805 - val_acc: 0.3822
#
# Epoch 00033: val_acc did not improve from 0.39965
# Epoch 34/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3125 - acc: 0.4405 - val_loss: 1.3710 - val_acc: 0.3770
#
# Epoch 00034: val_acc did not improve from 0.39965
# Epoch 35/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3044 - acc: 0.4405 - val_loss: 1.3801 - val_acc: 0.3822
#
# Epoch 00035: val_acc did not improve from 0.39965
# Epoch 36/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2994 - acc: 0.4453 - val_loss: 1.3673 - val_acc: 0.3770
#
# Epoch 00036: val_acc did not improve from 0.39965
# Epoch 37/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3064 - acc: 0.4379 - val_loss: 1.3831 - val_acc: 0.3874
#
# Epoch 00037: val_acc did not improve from 0.39965
# Epoch 38/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2967 - acc: 0.4479 - val_loss: 1.3962 - val_acc: 0.3770
#
# Epoch 00038: val_acc did not improve from 0.39965
# Epoch 39/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2770 - acc: 0.4532 - val_loss: 1.3888 - val_acc: 0.3578
#
# Epoch 00039: val_acc did not improve from 0.39965
# Epoch 40/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.2973 - acc: 0.4444 - val_loss: 1.3753 - val_acc: 0.3909
#
# Epoch 00040: val_acc did not improve from 0.39965
# Epoch 41/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.2929 - acc: 0.4349 - val_loss: 1.3725 - val_acc: 0.3839
#
# Epoch 00041: val_acc did not improve from 0.39965
# Epoch 42/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 1.2854 - acc: 0.4501 - val_loss: 1.4004 - val_acc: 0.3839
#
# Epoch 00042: val_acc did not improve from 0.39965
# Epoch 43/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.2682 - acc: 0.4601 - val_loss: 1.3716 - val_acc: 0.3857
#
# Epoch 00043: val_acc did not improve from 0.39965
# Epoch 44/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2860 - acc: 0.4558 - val_loss: 1.3761 - val_acc: 0.3752
#
# Epoch 00044: val_acc did not improve from 0.39965
# Epoch 45/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2767 - acc: 0.4475 - val_loss: 1.3727 - val_acc: 0.3909
#
# Epoch 00045: val_acc did not improve from 0.39965
# Epoch 46/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2699 - acc: 0.4527 - val_loss: 1.3864 - val_acc: 0.3700
#
# Epoch 00046: val_acc did not improve from 0.39965
# Epoch 47/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.2720 - acc: 0.4484 - val_loss: 1.3755 - val_acc: 0.3805
#
# Epoch 00047: val_acc did not improve from 0.39965
# Epoch 48/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2733 - acc: 0.4571 - val_loss: 1.3696 - val_acc: 0.3944
#
# Epoch 00048: val_acc did not improve from 0.39965
# Epoch 49/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.2572 - acc: 0.4693 - val_loss: 1.4039 - val_acc: 0.3717
#
# Epoch 00049: val_acc did not improve from 0.39965
# Epoch 50/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.2553 - acc: 0.4693 - val_loss: 1.3807 - val_acc: 0.3839
#
# Epoch 00050: val_acc did not improve from 0.39965
# Epoch 51/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2519 - acc: 0.4662 - val_loss: 1.3725 - val_acc: 0.3944
#
# Epoch 00051: val_acc did not improve from 0.39965
# Epoch 52/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2480 - acc: 0.4597 - val_loss: 1.4012 - val_acc: 0.3700
#
# Epoch 00052: val_acc did not improve from 0.39965
# Epoch 53/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2419 - acc: 0.4771 - val_loss: 1.3989 - val_acc: 0.3700
#
# Epoch 00053: val_acc did not improve from 0.39965
# Epoch 54/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2318 - acc: 0.4806 - val_loss: 1.4373 - val_acc: 0.3525
#
# Epoch 00054: val_acc did not improve from 0.39965
# Epoch 55/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2332 - acc: 0.4828 - val_loss: 1.3925 - val_acc: 0.3874
#
# Epoch 00055: val_acc did not improve from 0.39965
# Epoch 56/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2202 - acc: 0.4828 - val_loss: 1.4124 - val_acc: 0.3805
#
# Epoch 00056: val_acc did not improve from 0.39965
# Epoch 57/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2251 - acc: 0.4763 - val_loss: 1.3854 - val_acc: 0.3909
#
# Epoch 00057: val_acc did not improve from 0.39965
# Epoch 58/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2113 - acc: 0.4876 - val_loss: 1.4029 - val_acc: 0.3717
#
# Epoch 00058: val_acc did not improve from 0.39965
# Epoch 59/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2147 - acc: 0.4797 - val_loss: 1.3867 - val_acc: 0.3735
#
# Epoch 00059: val_acc did not improve from 0.39965
# Epoch 60/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1927 - acc: 0.4937 - val_loss: 1.4210 - val_acc: 0.3909
#
# Epoch 00060: val_acc did not improve from 0.39965
# Epoch 61/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2017 - acc: 0.4924 - val_loss: 1.4150 - val_acc: 0.3682
#
# Epoch 00061: val_acc did not improve from 0.39965
# Epoch 62/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.1991 - acc: 0.4976 - val_loss: 1.4115 - val_acc: 0.3787
#
# Epoch 00062: val_acc did not improve from 0.39965
# Epoch 63/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.1893 - acc: 0.4963 - val_loss: 1.4072 - val_acc: 0.3700
#
# Epoch 00063: val_acc did not improve from 0.39965
# Epoch 64/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1847 - acc: 0.4976 - val_loss: 1.4016 - val_acc: 0.3717
#
# Epoch 00064: val_acc did not improve from 0.39965
# Epoch 65/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.1777 - acc: 0.5068 - val_loss: 1.3966 - val_acc: 0.3927
#
# Epoch 00065: val_acc did not improve from 0.39965
# Epoch 66/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1789 - acc: 0.5068 - val_loss: 1.4293 - val_acc: 0.3717
#
# Epoch 00066: val_acc did not improve from 0.39965
# Epoch 67/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1654 - acc: 0.5203 - val_loss: 1.4134 - val_acc: 0.3822
#
# Epoch 00067: val_acc did not improve from 0.39965
# Epoch 68/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1612 - acc: 0.5133 - val_loss: 1.4140 - val_acc: 0.3665
#
# Epoch 00068: val_acc did not improve from 0.39965
# Epoch 69/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1367 - acc: 0.5207 - val_loss: 1.4488 - val_acc: 0.3665
#
# Epoch 00069: val_acc did not improve from 0.39965
# Epoch 70/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1487 - acc: 0.5133 - val_loss: 1.4592 - val_acc: 0.3647
#
# Epoch 00070: val_acc did not improve from 0.39965
# Epoch 71/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1217 - acc: 0.5416 - val_loss: 1.4391 - val_acc: 0.3805
#
# Epoch 00071: val_acc did not improve from 0.39965
# Epoch 72/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.1310 - acc: 0.5298 - val_loss: 1.4970 - val_acc: 0.3682
#
# Epoch 00072: val_acc did not improve from 0.39965
# Epoch 73/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.0978 - acc: 0.5464 - val_loss: 1.4589 - val_acc: 0.3735
#
# Epoch 00073: val_acc did not improve from 0.39965
# Epoch 74/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0982 - acc: 0.5412 - val_loss: 1.4491 - val_acc: 0.3700
#
# Epoch 00074: val_acc did not improve from 0.39965
# Epoch 75/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0879 - acc: 0.5473 - val_loss: 1.5257 - val_acc: 0.3490
#
# Epoch 00075: val_acc did not improve from 0.39965
# Epoch 76/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0810 - acc: 0.5495 - val_loss: 1.4722 - val_acc: 0.3892
#
# Epoch 00076: val_acc did not improve from 0.39965
# Epoch 77/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0633 - acc: 0.5656 - val_loss: 1.5267 - val_acc: 0.3647
#
# Epoch 00077: val_acc did not improve from 0.39965
# Epoch 78/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0443 - acc: 0.5804 - val_loss: 1.5324 - val_acc: 0.3682
#
# Epoch 00078: val_acc did not improve from 0.39965
# Epoch 79/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0470 - acc: 0.5725 - val_loss: 1.5312 - val_acc: 0.3822
#
# Epoch 00079: val_acc did not improve from 0.39965
# Epoch 80/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0353 - acc: 0.5717 - val_loss: 1.5430 - val_acc: 0.3578
#
# Epoch 00080: val_acc did not improve from 0.39965
# Epoch 81/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.0275 - acc: 0.5752 - val_loss: 1.5836 - val_acc: 0.3543
#
# Epoch 00081: val_acc did not improve from 0.39965
# Epoch 82/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.0155 - acc: 0.5791 - val_loss: 1.5406 - val_acc: 0.3805
#
# Epoch 00082: val_acc did not improve from 0.39965
# Epoch 83/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9930 - acc: 0.5834 - val_loss: 1.5527 - val_acc: 0.3525
#
# Epoch 00083: val_acc did not improve from 0.39965
# Epoch 84/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9873 - acc: 0.5869 - val_loss: 1.5854 - val_acc: 0.3770
#
# Epoch 00084: val_acc did not improve from 0.39965
# Epoch 85/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9677 - acc: 0.6139 - val_loss: 1.5927 - val_acc: 0.3682
#
# Epoch 00085: val_acc did not improve from 0.39965
# Epoch 86/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9481 - acc: 0.6192 - val_loss: 1.5358 - val_acc: 0.3647
#
# Epoch 00086: val_acc did not improve from 0.39965
# Epoch 87/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9343 - acc: 0.6205 - val_loss: 1.6877 - val_acc: 0.3543
#
# Epoch 00087: val_acc did not improve from 0.39965
# Epoch 88/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9198 - acc: 0.6253 - val_loss: 1.6554 - val_acc: 0.3630
#
# Epoch 00088: val_acc did not improve from 0.39965
# Epoch 89/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.9013 - acc: 0.6392 - val_loss: 1.6101 - val_acc: 0.3613
#
# Epoch 00089: val_acc did not improve from 0.39965
# Epoch 90/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.8635 - acc: 0.6558 - val_loss: 1.6613 - val_acc: 0.3717
#
# Epoch 00090: val_acc did not improve from 0.39965
# Epoch 91/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.8777 - acc: 0.6510 - val_loss: 1.6501 - val_acc: 0.3543
#
# Epoch 00091: val_acc did not improve from 0.39965
# Epoch 92/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.8597 - acc: 0.6514 - val_loss: 1.6915 - val_acc: 0.3578
#
# Epoch 00092: val_acc did not improve from 0.39965
# Epoch 93/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8262 - acc: 0.6719 - val_loss: 1.7366 - val_acc: 0.3176
#
# Epoch 00093: val_acc did not improve from 0.39965
# Epoch 94/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.8189 - acc: 0.6671 - val_loss: 1.7007 - val_acc: 0.3525
#
# Epoch 00094: val_acc did not improve from 0.39965
# Epoch 95/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8003 - acc: 0.6754 - val_loss: 1.7030 - val_acc: 0.3473
#
# Epoch 00095: val_acc did not improve from 0.39965
# Epoch 96/100
# 2295/2295 [==============================] - 4s 2ms/step - loss: 0.7928 - acc: 0.6815 - val_loss: 1.7375 - val_acc: 0.3560
#
# Epoch 00096: val_acc did not improve from 0.39965
# Epoch 97/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.7804 - acc: 0.6906 - val_loss: 1.7534 - val_acc: 0.3647
#
# Epoch 00097: val_acc did not improve from 0.39965
# Epoch 98/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 0.7716 - acc: 0.6941 - val_loss: 1.8018 - val_acc: 0.3613
#
# Epoch 00098: val_acc did not improve from 0.39965
# Epoch 99/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.7294 - acc: 0.7089 - val_loss: 1.7911 - val_acc: 0.3665
#
# Epoch 00099: val_acc did not improve from 0.39965
# Epoch 100/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.7201 - acc: 0.7242 - val_loss: 1.8027 - val_acc: 0.3595
#
# Epoch 00100: val_acc did not improve from 0.39965

# %%
import json,codecs
import numpy as np
def saveHist(path,history):

    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           if  type(history.history[key][0]) == np.float64:
               new_hist[key] = list(map(float, history.history[key]))

    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 

def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n


saveHist('CNNLSTM-ROLL-ATTENTION-BF-energie.hist',history)
hist=loadHist('CNNLSTM-ROLL-ATTENTION-BF-energie.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['acc'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_acc'],'b',label='CNNLSTM')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import load_model
model = load_model('CNNLSTM-ROLL-ATTENTION-BF-energie.h5',custom_objects={'CylindricalPadLSTMCNN':CylindricalPadLSTMCNN})

# %%
from sklearn.metrics import classification_report, confusion_matrix


print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9b79cd6acb42> in <module>()
#       3
#       4 print('Confusion Matrix')
# ----> 5 cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
#       6 print(cm)
#       7 scores = model.evaluate(X_test,y_test, verbose=0)
#
# NameError: name 'np' is not defined

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-BF-enegie.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
