# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv1D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer, InputSpec
from keras.layers import Input, Permute,  Reshape,  Lambda, Concatenate
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

K.set_image_dim_ordering("th")
SINGLE_ATTENTION_VECTOR = False


def attention_conv_block(inputs,timesteps):
    varsVec=[]
    for x in range(0,inputs.shape[2]):
            var=Lambda(lambda element : element[:,:,x])(inputs)
            var=contxt_padded = Lambda(lambda x: K.expand_dims(x,2))(var)
            var = Conv1D(filters=5 ,kernel_size=3,strides=1,padding='same',name='conv2_%d' % x)(var)
            var = Conv1D(filters=1 ,kernel_size=3,strides=1,padding='same',activation='softmax',name='conv_final_softmax_%d' % x)(var)
            varsVec.append(var)
    
    merged = concatenate(varsVec)
    output_attention_mul= Multiply()([inputs, merged])
    return output_attention_mul


class LSTMATTBFnet:
    @staticmethod
    def build(timeSteps,variables,classes):
        inputNet = Input(shape=(timeSteps,variables)) #batch_shape=(20, 7, 5) 
        attBlock=attention_conv_block(inputNet,timeSteps)
        #lstm=Bidirectional(LSTM(100,recurrent_dropout=0.4,dropout=0.4),merge_mode='concat')(inputNet) #worse using stateful=True
        lstm=Bidirectional(LSTM(100,recurrent_dropout=0.1,dropout=0.1,return_sequences=False),merge_mode='concat')(attBlock) #worse using stateful=True 
        
        # a softmax classifier
        classificationLayer=Dense(classes,activation='softmax')(lstm)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# /home/rjpg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_validation import train_test_split

def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
dfin = pd.read_csv('windows-size168-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size168-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.as_matrix().astype(np.float32),dfout.as_matrix().astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,168,8))
print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# /home/rjpg/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ############# total shapes #############
# (2868, 168, 8)
# 2868
# ############# train shapes #############
# (2295, 168, 8)
# (2295, 1)
# ############# test shapes #############
# (573, 168, 8)
# (573, 1)
# /home/rjpg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
IMG_ROWS, IMG_COLS = 168, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = LSTMATTBFnet.build(timeSteps=128,variables=3,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (573, 5)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 3)       0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128)          0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 128)          0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 128)          0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128, 1)       0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128, 1)       0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 128, 1)       0           lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2_0 (Conv1D)                (None, 128, 5)       20          lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv1D)                (None, 128, 5)       20          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv1D)                (None, 128, 5)       20          lambda_6[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_0 (Conv1D)   (None, 128, 1)       16          conv2_0[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_1 (Conv1D)   (None, 128, 1)       16          conv2_1[0][0]
# __________________________________________________________________________________________________
# conv_final_softmax_2 (Conv1D)   (None, 128, 1)       16          conv2_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 3)       0           conv_final_softmax_0[0][0]
#                                                                  conv_final_softmax_1[0][0]
#                                                                  conv_final_softmax_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 128, 3)       0           input_1[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 200)          83200       multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 5)            1005        bidirectional_1[0][0]
# ==================================================================================================
# Total params: 84,313
# Trainable params: 84,313
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
import matplotlib.pyplot as plt

modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)
plot_model(model, to_file='model-att-conv1d.pdf',show_shapes=True)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5', monitor='val_acc', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[reduce_lr,best_checkpoint])
# Out:
# Train on 2295 samples, validate on 573 samples
# Epoch 1/100
# 2295/2295 [==============================] - 24s 11ms/step - loss: 1.5601 - acc: 0.2715 - val_loss: 1.4992 - val_acc: 0.2827
#
# Epoch 00001: val_acc improved from -inf to 0.28272, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 2/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.4478 - acc: 0.3582 - val_loss: 1.4461 - val_acc: 0.3229
#
# Epoch 00002: val_acc improved from 0.28272 to 0.32286, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 3/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.4342 - acc: 0.3586 - val_loss: 1.4224 - val_acc: 0.2984
#
# Epoch 00003: val_acc did not improve from 0.32286
# Epoch 4/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.4372 - acc: 0.3699 - val_loss: 1.4124 - val_acc: 0.3368
#
# Epoch 00004: val_acc improved from 0.32286 to 0.33682, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 5/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.4066 - acc: 0.3704 - val_loss: 1.3981 - val_acc: 0.3560
#
# Epoch 00005: val_acc improved from 0.33682 to 0.35602, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 6/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.4158 - acc: 0.3773 - val_loss: 1.4091 - val_acc: 0.3682
#
# Epoch 00006: val_acc improved from 0.35602 to 0.36824, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 7/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3979 - acc: 0.3813 - val_loss: 1.4441 - val_acc: 0.3333
#
# Epoch 00007: val_acc did not improve from 0.36824
# Epoch 8/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3921 - acc: 0.3856 - val_loss: 1.4174 - val_acc: 0.3997
#
# Epoch 00008: val_acc improved from 0.36824 to 0.39965, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 9/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3893 - acc: 0.3847 - val_loss: 1.3918 - val_acc: 0.4014
#
# Epoch 00009: val_acc improved from 0.39965 to 0.40140, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 10/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3794 - acc: 0.3869 - val_loss: 1.3822 - val_acc: 0.3560
#
# Epoch 00010: val_acc did not improve from 0.40140
# Epoch 11/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3625 - acc: 0.4000 - val_loss: 1.3899 - val_acc: 0.3787
#
# Epoch 00011: val_acc did not improve from 0.40140
# Epoch 12/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3554 - acc: 0.3917 - val_loss: 1.3635 - val_acc: 0.3927
#
# Epoch 00012: val_acc did not improve from 0.40140
# Epoch 13/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3588 - acc: 0.4048 - val_loss: 1.3925 - val_acc: 0.3717
#
# Epoch 00013: val_acc did not improve from 0.40140
# Epoch 14/100
# 2295/2295 [==============================] - 22s 10ms/step - loss: 1.3600 - acc: 0.4070 - val_loss: 1.3679 - val_acc: 0.3735
#
# Epoch 00014: val_acc did not improve from 0.40140
# Epoch 15/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3477 - acc: 0.3952 - val_loss: 1.3732 - val_acc: 0.3787
#
# Epoch 00015: val_acc did not improve from 0.40140
# Epoch 16/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3404 - acc: 0.4122 - val_loss: 1.3762 - val_acc: 0.4049
#
# Epoch 00016: val_acc improved from 0.40140 to 0.40489, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 17/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3548 - acc: 0.4044 - val_loss: 1.3781 - val_acc: 0.3665
#
# Epoch 00017: val_acc did not improve from 0.40489
# Epoch 18/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3421 - acc: 0.4122 - val_loss: 1.3715 - val_acc: 0.4031
#
# Epoch 00018: val_acc did not improve from 0.40489
# Epoch 19/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3309 - acc: 0.4100 - val_loss: 1.3647 - val_acc: 0.4049
#
# Epoch 00019: val_acc did not improve from 0.40489
# Epoch 20/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3354 - acc: 0.4031 - val_loss: 1.3645 - val_acc: 0.4031
#
# Epoch 00020: val_acc did not improve from 0.40489
# Epoch 21/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3268 - acc: 0.4344 - val_loss: 1.3582 - val_acc: 0.4049
#
# Epoch 00021: val_acc did not improve from 0.40489
# Epoch 22/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3331 - acc: 0.4096 - val_loss: 1.3600 - val_acc: 0.4206
#
# Epoch 00022: val_acc improved from 0.40489 to 0.42059, saving model to LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5
# Epoch 23/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3353 - acc: 0.4144 - val_loss: 1.3579 - val_acc: 0.4031
#
# Epoch 00023: val_acc did not improve from 0.42059
# Epoch 24/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3253 - acc: 0.4261 - val_loss: 1.3563 - val_acc: 0.4171
#
# Epoch 00024: val_acc did not improve from 0.42059
# Epoch 25/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3273 - acc: 0.4083 - val_loss: 1.3565 - val_acc: 0.4101
#
# Epoch 00025: val_acc did not improve from 0.42059
# Epoch 26/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3280 - acc: 0.4248 - val_loss: 1.3551 - val_acc: 0.4014
#
# Epoch 00026: val_acc did not improve from 0.42059
# Epoch 27/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3307 - acc: 0.4205 - val_loss: 1.3603 - val_acc: 0.4014
#
# Epoch 00027: val_acc did not improve from 0.42059
# Epoch 28/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3318 - acc: 0.4170 - val_loss: 1.3575 - val_acc: 0.3927
#
# Epoch 00028: val_acc did not improve from 0.42059
# Epoch 29/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3209 - acc: 0.4187 - val_loss: 1.3551 - val_acc: 0.3979
#
# Epoch 00029: val_acc did not improve from 0.42059
# Epoch 30/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3169 - acc: 0.4257 - val_loss: 1.3543 - val_acc: 0.3962
#
# Epoch 00030: val_acc did not improve from 0.42059
# Epoch 31/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3273 - acc: 0.4214 - val_loss: 1.3555 - val_acc: 0.4031
#
# Epoch 00031: val_acc did not improve from 0.42059
# Epoch 32/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3148 - acc: 0.4118 - val_loss: 1.3538 - val_acc: 0.4084
#
# Epoch 00032: val_acc did not improve from 0.42059
# Epoch 33/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3252 - acc: 0.4065 - val_loss: 1.3552 - val_acc: 0.3962
#
# Epoch 00033: val_acc did not improve from 0.42059
# Epoch 34/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3171 - acc: 0.4327 - val_loss: 1.3588 - val_acc: 0.3997
#
# Epoch 00034: val_acc did not improve from 0.42059
# Epoch 35/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3325 - acc: 0.4100 - val_loss: 1.3554 - val_acc: 0.3979
#
# Epoch 00035: val_acc did not improve from 0.42059
# Epoch 36/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3175 - acc: 0.4153 - val_loss: 1.3544 - val_acc: 0.3927
#
# Epoch 00036: val_acc did not improve from 0.42059
# Epoch 37/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3167 - acc: 0.4109 - val_loss: 1.3524 - val_acc: 0.3892
#
# Epoch 00037: val_acc did not improve from 0.42059
# Epoch 38/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3217 - acc: 0.4157 - val_loss: 1.3542 - val_acc: 0.3857
#
# Epoch 00038: val_acc did not improve from 0.42059
# Epoch 39/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3166 - acc: 0.4222 - val_loss: 1.3523 - val_acc: 0.3787
#
# Epoch 00039: val_acc did not improve from 0.42059
# Epoch 40/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3214 - acc: 0.4235 - val_loss: 1.3527 - val_acc: 0.3857
#
# Epoch 00040: val_acc did not improve from 0.42059
# Epoch 41/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3108 - acc: 0.4218 - val_loss: 1.3568 - val_acc: 0.3857
#
# Epoch 00041: val_acc did not improve from 0.42059
# Epoch 42/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3118 - acc: 0.4266 - val_loss: 1.3554 - val_acc: 0.3857
#
# Epoch 00042: val_acc did not improve from 0.42059
# Epoch 43/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3167 - acc: 0.4309 - val_loss: 1.3565 - val_acc: 0.3892
#
# Epoch 00043: val_acc did not improve from 0.42059
# Epoch 44/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3109 - acc: 0.4122 - val_loss: 1.3529 - val_acc: 0.3962
#
# Epoch 00044: val_acc did not improve from 0.42059
# Epoch 45/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3116 - acc: 0.4288 - val_loss: 1.3578 - val_acc: 0.3944
#
# Epoch 00045: val_acc did not improve from 0.42059
# Epoch 46/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3148 - acc: 0.4227 - val_loss: 1.3599 - val_acc: 0.3892
#
# Epoch 00046: val_acc did not improve from 0.42059
# Epoch 47/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3170 - acc: 0.4235 - val_loss: 1.3634 - val_acc: 0.4049
#
# Epoch 00047: val_acc did not improve from 0.42059
# Epoch 48/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3079 - acc: 0.4279 - val_loss: 1.3556 - val_acc: 0.4014
#
# Epoch 00048: val_acc did not improve from 0.42059
# Epoch 49/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3201 - acc: 0.4244 - val_loss: 1.3592 - val_acc: 0.3839
#
# Epoch 00049: val_acc did not improve from 0.42059
# Epoch 50/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3137 - acc: 0.4296 - val_loss: 1.3633 - val_acc: 0.3857
#
# Epoch 00050: val_acc did not improve from 0.42059
# Epoch 51/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3246 - acc: 0.4161 - val_loss: 1.3556 - val_acc: 0.3979
#
# Epoch 00051: val_acc did not improve from 0.42059
# Epoch 52/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3038 - acc: 0.4235 - val_loss: 1.3619 - val_acc: 0.3752
#
# Epoch 00052: val_acc did not improve from 0.42059
# Epoch 53/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3059 - acc: 0.4305 - val_loss: 1.3606 - val_acc: 0.3735
#
# Epoch 00053: val_acc did not improve from 0.42059
# Epoch 54/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3251 - acc: 0.4227 - val_loss: 1.3611 - val_acc: 0.3874
#
# Epoch 00054: val_acc did not improve from 0.42059
# Epoch 55/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3134 - acc: 0.4327 - val_loss: 1.3598 - val_acc: 0.3735
#
# Epoch 00055: val_acc did not improve from 0.42059
# Epoch 56/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3000 - acc: 0.4231 - val_loss: 1.3608 - val_acc: 0.3927
#
# Epoch 00056: val_acc did not improve from 0.42059
# Epoch 57/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3095 - acc: 0.4253 - val_loss: 1.3546 - val_acc: 0.3979
#
# Epoch 00057: val_acc did not improve from 0.42059
# Epoch 58/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.2978 - acc: 0.4257 - val_loss: 1.3546 - val_acc: 0.3962
#
# Epoch 00058: val_acc did not improve from 0.42059
# Epoch 59/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3082 - acc: 0.4240 - val_loss: 1.3555 - val_acc: 0.3770
#
# Epoch 00059: val_acc did not improve from 0.42059
# Epoch 60/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3110 - acc: 0.4187 - val_loss: 1.3576 - val_acc: 0.3909
#
# Epoch 00060: val_acc did not improve from 0.42059
# Epoch 61/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3062 - acc: 0.4253 - val_loss: 1.3585 - val_acc: 0.3909
#
# Epoch 00061: val_acc did not improve from 0.42059
# Epoch 62/100
# 2295/2295 [==============================] - 22s 9ms/step - loss: 1.3062 - acc: 0.4231 - val_loss: 1.3642 - val_acc: 0.3997
#
# Epoch 00062: val_acc did not improve from 0.42059
# Epoch 63/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3059 - acc: 0.4257 - val_loss: 1.3556 - val_acc: 0.3874
#
# Epoch 00063: val_acc did not improve from 0.42059
# Epoch 64/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3045 - acc: 0.4362 - val_loss: 1.3628 - val_acc: 0.3822
#
# Epoch 00064: val_acc did not improve from 0.42059
# Epoch 65/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3086 - acc: 0.4170 - val_loss: 1.3541 - val_acc: 0.3874
#
# Epoch 00065: val_acc did not improve from 0.42059
# Epoch 66/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3075 - acc: 0.4318 - val_loss: 1.3540 - val_acc: 0.3874
#
# Epoch 00066: val_acc did not improve from 0.42059
# Epoch 67/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3120 - acc: 0.4139 - val_loss: 1.3589 - val_acc: 0.3839
#
# Epoch 00067: val_acc did not improve from 0.42059
# Epoch 68/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3022 - acc: 0.4183 - val_loss: 1.3553 - val_acc: 0.3927
#
# Epoch 00068: val_acc did not improve from 0.42059
# Epoch 69/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3028 - acc: 0.4192 - val_loss: 1.3545 - val_acc: 0.3857
#
# Epoch 00069: val_acc did not improve from 0.42059
# Epoch 70/100
# 2295/2295 [==============================] - 21s 9ms/step - loss: 1.3056 - acc: 0.4314 - val_loss: 1.3512 - val_acc: 0.3927
#
# Epoch 00070: val_acc did not improve from 0.42059
# Epoch 71/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2836 - acc: 0.4436 - val_loss: 1.3590 - val_acc: 0.3682
#
# Epoch 00071: val_acc did not improve from 0.42059
# Epoch 72/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3081 - acc: 0.4192 - val_loss: 1.3578 - val_acc: 0.3944
#
# Epoch 00072: val_acc did not improve from 0.42059
# Epoch 73/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2951 - acc: 0.4283 - val_loss: 1.3548 - val_acc: 0.3979
#
# Epoch 00073: val_acc did not improve from 0.42059
# Epoch 74/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2990 - acc: 0.4283 - val_loss: 1.3587 - val_acc: 0.3805
#
# Epoch 00074: val_acc did not improve from 0.42059
# Epoch 75/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2995 - acc: 0.4166 - val_loss: 1.3592 - val_acc: 0.3787
#
# Epoch 00075: val_acc did not improve from 0.42059
# Epoch 76/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3046 - acc: 0.4275 - val_loss: 1.3576 - val_acc: 0.3787
#
# Epoch 00076: val_acc did not improve from 0.42059
# Epoch 77/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3065 - acc: 0.4161 - val_loss: 1.3602 - val_acc: 0.3770
#
# Epoch 00077: val_acc did not improve from 0.42059
# Epoch 78/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2962 - acc: 0.4427 - val_loss: 1.3561 - val_acc: 0.3892
#
# Epoch 00078: val_acc did not improve from 0.42059
# Epoch 79/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3079 - acc: 0.4227 - val_loss: 1.3562 - val_acc: 0.3909
#
# Epoch 00079: val_acc did not improve from 0.42059
# Epoch 80/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2993 - acc: 0.4279 - val_loss: 1.3526 - val_acc: 0.3892
#
# Epoch 00080: val_acc did not improve from 0.42059
# Epoch 81/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2994 - acc: 0.4144 - val_loss: 1.3537 - val_acc: 0.4066
#
# Epoch 00081: val_acc did not improve from 0.42059
# Epoch 82/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3117 - acc: 0.4235 - val_loss: 1.3591 - val_acc: 0.3735
#
# Epoch 00082: val_acc did not improve from 0.42059
# Epoch 83/100
# 2295/2295 [==============================] - 19s 8ms/step - loss: 1.3004 - acc: 0.4301 - val_loss: 1.3561 - val_acc: 0.3962
#
# Epoch 00083: val_acc did not improve from 0.42059
# Epoch 84/100
# 2295/2295 [==============================] - 19s 8ms/step - loss: 1.3100 - acc: 0.4305 - val_loss: 1.3595 - val_acc: 0.4031
# Epoch 00084: val_acc did not improve from 0.42059
# Epoch 85/100
# 2295/2295 [==============================] - 19s 8ms/step - loss: 1.3091 - acc: 0.4275 - val_loss: 1.3579 - val_acc: 0.3805
#
# Epoch 00085: val_acc did not improve from 0.42059
# Epoch 86/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3033 - acc: 0.4257 - val_loss: 1.3594 - val_acc: 0.3839
#
# Epoch 00086: val_acc did not improve from 0.42059
# Epoch 87/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3092 - acc: 0.4279 - val_loss: 1.3667 - val_acc: 0.3752
#
# Epoch 00087: val_acc did not improve from 0.42059
# Epoch 88/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2949 - acc: 0.4235 - val_loss: 1.3588 - val_acc: 0.3752
#
# Epoch 00088: val_acc did not improve from 0.42059
# Epoch 89/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2978 - acc: 0.4375 - val_loss: 1.3625 - val_acc: 0.3752
#
# Epoch 00089: val_acc did not improve from 0.42059
# Epoch 90/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2895 - acc: 0.4362 - val_loss: 1.3563 - val_acc: 0.4031
#
# Epoch 00090: val_acc did not improve from 0.42059
# Epoch 91/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2962 - acc: 0.4235 - val_loss: 1.3573 - val_acc: 0.3630
#
# Epoch 00091: val_acc did not improve from 0.42059
# Epoch 92/100
# 2295/2295 [==============================] - 19s 8ms/step - loss: 1.3066 - acc: 0.4288 - val_loss: 1.3583 - val_acc: 0.3822
#
# Epoch 00092: val_acc did not improve from 0.42059
# Epoch 93/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2940 - acc: 0.4257 - val_loss: 1.3578 - val_acc: 0.3682
#
# Epoch 00093: val_acc did not improve from 0.42059
# Epoch 94/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2901 - acc: 0.4353 - val_loss: 1.3523 - val_acc: 0.3857
#
# Epoch 00094: val_acc did not improve from 0.42059
# Epoch 95/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2950 - acc: 0.4314 - val_loss: 1.3523 - val_acc: 0.4014
#
# Epoch 00095: val_acc did not improve from 0.42059
# Epoch 96/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2953 - acc: 0.4327 - val_loss: 1.3540 - val_acc: 0.3822
#
# Epoch 00096: val_acc did not improve from 0.42059
# Epoch 97/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.2955 - acc: 0.4353 - val_loss: 1.3537 - val_acc: 0.3770
#
# Epoch 00097: val_acc did not improve from 0.42059
# Epoch 98/100
# 2295/2295 [==============================] - 20s 8ms/step - loss: 1.3096 - acc: 0.4209 - val_loss: 1.3563 - val_acc: 0.3962
#
# Epoch 00098: val_acc did not improve from 0.42059
# Epoch 99/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3050 - acc: 0.4222 - val_loss: 1.3511 - val_acc: 0.3839
#
# Epoch 00099: val_acc did not improve from 0.42059
# Epoch 100/100
# 2295/2295 [==============================] - 20s 9ms/step - loss: 1.3080 - acc: 0.4161 - val_loss: 1.3542 - val_acc: 0.3839
#
# Epoch 00100: val_acc did not improve from 0.42059

# %%
import json,codecs
import numpy as np
def saveHist(path,history):

    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           if  type(history.history[key][0]) == np.float64:
               new_hist[key] = list(map(float, history.history[key]))

    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 

def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n


saveHist('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.hist',history)
hist=loadHist('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['acc'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_acc'],'b',label='DNNC')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

from keras.models import load_model
model = load_model('LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie.h5')

print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# [[70 33  4  7  1]
#  [22 76 18 14 10]
#  [ 9 62 38 20 12]
#  [ 3 36 16 36 17]
#  [ 4 11 14 19 21]]
# Dados Validação acc: 42.06%
#              precision    recall  f1-score   support
#
#           0     0.6481    0.6087    0.6278       115
#           1     0.3486    0.5429    0.4246       140
#           2     0.4222    0.2695    0.3290       141
#           3     0.3750    0.3333    0.3529       108
#           4     0.3443    0.3043    0.3231        69
#
# avg / total     0.4313    0.4206    0.4161       573

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-AF-BIDIRECT-SPLIT-energie-CM.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
