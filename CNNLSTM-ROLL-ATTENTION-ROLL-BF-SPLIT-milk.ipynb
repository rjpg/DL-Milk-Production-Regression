# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv3D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer,InputSpec
from keras.layers import ConvLSTM2D
from keras.layers import Input, Permute,  Reshape,  Lambda, Concatenate
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

K.set_image_dim_ordering("th")

class CylindricalPadLSTMCNN(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadLSTMCNN, self).__init__(**kwargs)
        self.n = n
        self.m = m
        assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadLSTMCNN, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,:,testElement.shape[4]-self.n:testElement.shape[4]]
        result=tf.concat([testElement,firstColumns], axis=4)
        result=tf.concat([lastColumns,result], axis=4)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,:,0:self.m,:]
            
            y = tf.fill(tf.shape(firstRows), 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=3)
            result=tf.concat([result,y], axis=3)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadLSTMCNN, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

class CylindricalPad(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPad, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPad, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
        result=tf.concat([testElement,firstColumns], axis=3)
        result=tf.concat([lastColumns,result], axis=3)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,0:self.m,:]
            
            #y = tf.fill(tf.shape(firstRows), 0.)
            sa=tf.shape(firstRows)[0]
            sb=tf.shape(firstRows)[1]
            sc=self.m
            sd=tf.shape(firstRows)[3]
            y = tf.fill([sa, sb,sc, sd], 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=2)
            
            ########## only add 0's to de left for casusal pading
            #############result=tf.concat([result,y], axis=2)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPad, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
print("CylindricalPad class layer defined")

def attention_3d_block(inputs,timesteps):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    time_steps=timesteps
    print("input shape ",inputs.shape)
    print(input_dim)
    #print(time_steps)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    
    #a_probs=(inputs)
    
    #a_probs = Permute((2, 1))(inputs)
    #a_probs = K.transpose(inputs,(0,2,1,3,4))
    #a_probs = K.permute_dimensions(inputs,(0,2,1,3,4))
    
    #print("after permute a_probs shape ",a_probs.shape)
    #a_probs=CylindricalPadLSTMCNN(m=0,n=1)(a_probs)
    
    #a_probs = Conv3D(time_steps,(1,1,3),strides=1,padding='valid',activation='softmax')(a_probs)
    
    #a_probs = Conv3D(time_steps,(1,1,3),strides=1,padding='valid',activation='softmax')(a_probs)
    
    #print("after conv a_probs shape ",a_probs.shape)
    
    varsVec=[]
    for x in range(0,inputs.shape[4]):
            var=Lambda(lambda element : element[:,:,:,:,x])(inputs)
            #var=contxt_padded = Lambda(lambda x: K.expand_dims(x,1))(var)
            #var=K.expand_dims(var, 2)
            print("inside")
            print(var.shape)
            var = Permute((2, 3, 1))(var)
            #var = Permute((2, 1, 3))(var)
            #var = var[:,:,np.newaxis]
            #var = Conv1D(filters=5 ,kernel_size=5,strides=1,padding='same',name='conv1_%d' % x)(var)
            print("inside Cyl")
            print(var.shape)
            var = CylindricalPad(m=2,n=1)(var)
           
            var = Conv2D(filters=5 ,kernel_size=(3,3),strides=1,padding='valid',name='conv2_%d' % x)(var)
            var = CylindricalPad(m=2,n=1)(var)
            var = Conv2D(filters=1 ,kernel_size=(3,3),strides=1,padding='valid',activation='softmax',name='conv_final_softmax_%d' % x)(var)
            var = Permute((3, 1,2))(var)
            #var = Permute((2, 1,3))(var)
            var=contxt_padded = Lambda(lambda x: K.expand_dims(x,4))(var)
            varsVec.append(var)
    
    #merged = varsVec
    merged = concatenate(varsVec)
    print(merged.shape)
    
    
    #a = Permute((2, 1))(inputs)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #a = Reshape((-1,input_dim, time_steps))(a) # this line is not useful. It's just to know which dimension is what.
    #a = Conv2D(100,3,padding='same')(a)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #a = concatenate(neurVec)
    #a_probs = Dense(100, activation='softmax')(a)
    #a = Reshape((input_dim, time_steps))(a)
    #a_probs =  K.permute_dimensions(a_probs,(0,2,1,3,4)) #, name='attention_vec ' % (depth)
    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul= Multiply()([inputs, merged]) #name='attention_mul'
    return output_attention_mul


class CNNLSTMROLL:
    @staticmethod
    def build(timeSteps,rows, cols,classes):
        
        inputNet = Input(shape=(timeSteps,1,rows, cols)) #batch_shape=(20, 7, 5) 
        #cyPad1=CylindricalPadLSTMCNN(m=0,n=3)(inputNet)
        ##convlstm2d=ConvLSTM2D(5, kernel_size=(2,7), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=True)(cyPad1)
        #Bidirectional(              ,merge_mode='concat')
        #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
        #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
        attention_mul = attention_3d_block(inputNet,timeSteps)
        cyPad2=CylindricalPadLSTMCNN(m=0,n=3)(attention_mul)
        convlstm2d=ConvLSTM2D(20, kernel_size=(2,7), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=False)(cyPad2)
        flat = Flatten()(convlstm2d)
        
        #flat=Flatten()(convlstm2d)

        classificationLayer=Dense(classes)(flat)
        classificationLayer=Activation("softmax")(classificationLayer)
        
        #classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# CylindricalPad class layer defined

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_validation import train_test_split

def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
#dfin = pd.read_csv('windows-size72-step12.csv',header=None)  #inputs 72 lines per sample
#dfout = pd.read_csv('out-class-size72-step12.csv',header=None)  #output classes 
dfin = pd.read_csv('windows-size168-step24-Normalized.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size168-step24.csv',header=None)  #output classes 

total_inputs,total_output = dfin.as_matrix().astype(np.float32),dfout.as_matrix().astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,168,8))
total_inputs = np.reshape(total_inputs, (-1,7,24,8))

print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (1432, 7, 24, 8)
# 1432
# ############# train shapes #############
# (1146, 7, 24, 8)
# (1146, 1)
# ############# test shapes #############
# (286, 7, 24, 8)
# (286, 1)
# /home/rjpg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs[:,:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:,:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = CNNLSTMROLL.build(timeSteps=7,rows=24, cols=8,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (286, 5)
# input shape  (?, ?, 10, 23, 8)
# 10
# inside
# (?, ?, 10, 23)
# inside Cyl
# (?, 10, 23, ?)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     454                 preferred_dtype=default_dtype,
# --> 455                 as_ref=input_arg.is_ref)
#     456             if input_arg.number_attr and len(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_n_to_tensor(values, dtype, name, as_ref, preferred_dtype, ctx)
#    1171             preferred_dtype=preferred_dtype,
# -> 1172             ctx=ctx))
#    1173   return ret
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1106     if ret is None:
# -> 1107       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1108
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _dimension_tensor_conversion_function(d, dtype, name, as_ref)
#     269   if d.value is None:
# --> 270     raise ValueError("Cannot convert an unknown Dimension to a Tensor: %s" % d)
#     271   if dtype is not None:
#
# ValueError: Cannot convert an unknown Dimension to a Tensor: ?
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-64cd070aeb91> in <module>()
#      11 OPTIMIZER = Adam()
#      12
# ---> 13 model = CNNLSTMROLL.build(timeSteps=7,rows=24, cols=8,classes=5)
#      14 model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
#      15 	metrics=["accuracy"])
#
# <ipython-input-7-7c1b8d1932a0> in build(timeSteps, rows, cols, classes)
#     232         #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
#     233         #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
# --> 234         attention_mul = attention_3d_block(convlstm2d,timeSteps)
#     235         cyPad2=CylindricalPadLSTMCNN(m=0,n=3)(attention_mul)
#     236         convlstm2d=ConvLSTM2D(20, kernel_size=(2,7), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=False)(cyPad2)
#
# <ipython-input-7-7c1b8d1932a0> in attention_3d_block(inputs, timesteps)
#     187             print("inside Cyl")
#     188             print(var.shape)
# --> 189             var = CylindricalPad(m=2,n=1)(var)
#     190
#     191             var = Conv2D(filters=5 ,kernel_size=(3,3),strides=1,padding='valid',name='conv2_%d' % x)(var)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     458             # Actually call the layer,
#     459             # collecting output(s), mask(s), and shape(s).
# --> 460             output = self.call(inputs, **kwargs)
#     461             output_mask = self.compute_mask(inputs, previous_mask)
#     462
#
# <ipython-input-7-7c1b8d1932a0> in call(self, testElement, mask)
#     108     def call(self,testElement, mask=None):
#     109         firstColumns=testElement[:,:,:,0:self.n]
# --> 110         lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
#     111         result=tf.concat([testElement,firstColumns], axis=3)
#     112         result=tf.concat([lastColumns,result], axis=3)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     496                       [tensor] + begin + end + strides) as name:
#     497     if begin:
# --> 498       packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
#     499                                                   stack(strides))
#     500       if (packed_begin.dtype == dtypes.int64 or
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in stack(values, axis, name)
#     872                                                       expanded_num_dims))
#     873
# --> 874   return gen_array_ops.pack(values, axis=axis, name=name)
#     875
#     876
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in pack(values, axis, name)
#    4591     axis = _execute.make_int(axis, "axis")
#    4592     _, _, _op = _op_def_lib._apply_op_helper(
# -> 4593         "Pack", values=values, axis=axis, name=name)
#    4594     _result = _op.outputs[:]
#    4595     _inputs_flat = _op.inputs
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     481                                 (prefix, dtype.name))
#     482               else:
# --> 483                 raise TypeError("%s that don't all match." % prefix)
#     484             else:
#     485               raise TypeError("%s that are invalid." % prefix)
#
# TypeError: Tensors in list passed to 'values' of 'Pack' Op have types [int32, int32, int32, <NOT CONVERTIBLE TO TENSOR>] that don't all match.

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5', monitor='val_acc', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[best_checkpoint])
# Out:
# Train on 1146 samples, validate on 286 samples
# Epoch 1/100
# 1146/1146 [==============================] - 5s 4ms/step - loss: 1.5868 - acc: 0.2644 - val_loss: 1.6134 - val_acc: 0.1503
#
# Epoch 00001: val_acc improved from -inf to 0.15035, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 2/100
# 1146/1146 [==============================] - 1s 765us/step - loss: 1.4371 - acc: 0.3709 - val_loss: 1.4405 - val_acc: 0.3042
#
# Epoch 00002: val_acc improved from 0.15035 to 0.30420, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 3/100
# 1146/1146 [==============================] - 1s 799us/step - loss: 1.3370 - acc: 0.4232 - val_loss: 1.3996 - val_acc: 0.3741
#
# Epoch 00003: val_acc improved from 0.30420 to 0.37413, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 4/100
# 1146/1146 [==============================] - 1s 799us/step - loss: 1.3004 - acc: 0.4398 - val_loss: 1.3810 - val_acc: 0.3811
#
# Epoch 00004: val_acc improved from 0.37413 to 0.38112, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 5/100
# 1146/1146 [==============================] - 1s 835us/step - loss: 1.3028 - acc: 0.4319 - val_loss: 1.3760 - val_acc: 0.3881
#
# Epoch 00005: val_acc improved from 0.38112 to 0.38811, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 6/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 1.2861 - acc: 0.4424 - val_loss: 1.3710 - val_acc: 0.3776
#
# Epoch 00006: val_acc did not improve from 0.38811
# Epoch 7/100
# 1146/1146 [==============================] - 1s 809us/step - loss: 1.2812 - acc: 0.4538 - val_loss: 1.3696 - val_acc: 0.3671
#
# Epoch 00007: val_acc did not improve from 0.38811
# Epoch 8/100
# 1146/1146 [==============================] - 1s 809us/step - loss: 1.2805 - acc: 0.4564 - val_loss: 1.3596 - val_acc: 0.3951
#
# Epoch 00008: val_acc improved from 0.38811 to 0.39510, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 9/100
# 1146/1146 [==============================] - 1s 813us/step - loss: 1.2725 - acc: 0.4555 - val_loss: 1.3564 - val_acc: 0.3916
#
# Epoch 00009: val_acc did not improve from 0.39510
# Epoch 10/100
# 1146/1146 [==============================] - 1s 819us/step - loss: 1.2763 - acc: 0.4311 - val_loss: 1.3693 - val_acc: 0.4021
#
# Epoch 00010: val_acc improved from 0.39510 to 0.40210, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 11/100
# 1146/1146 [==============================] - 1s 796us/step - loss: 1.2651 - acc: 0.4433 - val_loss: 1.3460 - val_acc: 0.3846
#
# Epoch 00011: val_acc did not improve from 0.40210
# Epoch 12/100
# 1146/1146 [==============================] - 1s 818us/step - loss: 1.2532 - acc: 0.4520 - val_loss: 1.3403 - val_acc: 0.3916
#
# Epoch 00012: val_acc did not improve from 0.40210
# Epoch 13/100
# 1146/1146 [==============================] - 1s 801us/step - loss: 1.2564 - acc: 0.4529 - val_loss: 1.3449 - val_acc: 0.3951
#
# Epoch 00013: val_acc did not improve from 0.40210
# Epoch 14/100
# 1146/1146 [==============================] - 1s 795us/step - loss: 1.2317 - acc: 0.4695 - val_loss: 1.3414 - val_acc: 0.3846
#
# Epoch 00014: val_acc did not improve from 0.40210
# Epoch 15/100
# 1146/1146 [==============================] - 1s 837us/step - loss: 1.2380 - acc: 0.4625 - val_loss: 1.3457 - val_acc: 0.3881
#
# Epoch 00015: val_acc did not improve from 0.40210
# Epoch 16/100
# 1146/1146 [==============================] - 1s 812us/step - loss: 1.2330 - acc: 0.4791 - val_loss: 1.3227 - val_acc: 0.4126
#
# Epoch 00016: val_acc improved from 0.40210 to 0.41259, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 17/100
# 1146/1146 [==============================] - 1s 807us/step - loss: 1.2348 - acc: 0.4695 - val_loss: 1.3193 - val_acc: 0.3776
#
# Epoch 00017: val_acc did not improve from 0.41259
# Epoch 18/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 1.2251 - acc: 0.4616 - val_loss: 1.3421 - val_acc: 0.3986
#
# Epoch 00018: val_acc did not improve from 0.41259
# Epoch 19/100
# 1146/1146 [==============================] - 1s 804us/step - loss: 1.2264 - acc: 0.4721 - val_loss: 1.3406 - val_acc: 0.3776
#
# Epoch 00019: val_acc did not improve from 0.41259
# Epoch 20/100
# 1146/1146 [==============================] - 1s 798us/step - loss: 1.2182 - acc: 0.4721 - val_loss: 1.3200 - val_acc: 0.4196
#
# Epoch 00020: val_acc improved from 0.41259 to 0.41958, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 21/100
# 1146/1146 [==============================] - 1s 793us/step - loss: 1.2067 - acc: 0.4791 - val_loss: 1.3367 - val_acc: 0.3846
#
# Epoch 00021: val_acc did not improve from 0.41958
# Epoch 22/100
# 1146/1146 [==============================] - 1s 861us/step - loss: 1.1905 - acc: 0.5218 - val_loss: 1.3164 - val_acc: 0.4056
#
# Epoch 00022: val_acc did not improve from 0.41958
# Epoch 23/100
# 1146/1146 [==============================] - 1s 828us/step - loss: 1.2060 - acc: 0.4808 - val_loss: 1.3253 - val_acc: 0.3986
#
# Epoch 00023: val_acc did not improve from 0.41958
# Epoch 24/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 1.2059 - acc: 0.4712 - val_loss: 1.3162 - val_acc: 0.4196
#
# Epoch 00024: val_acc did not improve from 0.41958
# Epoch 25/100
# 1146/1146 [==============================] - 1s 811us/step - loss: 1.1816 - acc: 0.5026 - val_loss: 1.3118 - val_acc: 0.3986
#
# Epoch 00025: val_acc did not improve from 0.41958
# Epoch 26/100
# 1146/1146 [==============================] - 1s 797us/step - loss: 1.1764 - acc: 0.4956 - val_loss: 1.3585 - val_acc: 0.4021
#
# Epoch 00026: val_acc did not improve from 0.41958
# Epoch 27/100
# 1146/1146 [==============================] - 1s 821us/step - loss: 1.1852 - acc: 0.4843 - val_loss: 1.3246 - val_acc: 0.4336
#
# Epoch 00027: val_acc improved from 0.41958 to 0.43357, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 28/100
# 1146/1146 [==============================] - 1s 804us/step - loss: 1.1752 - acc: 0.5061 - val_loss: 1.3217 - val_acc: 0.4091
#
# Epoch 00028: val_acc did not improve from 0.43357
# Epoch 29/100
# 1146/1146 [==============================] - 1s 853us/step - loss: 1.1592 - acc: 0.5271 - val_loss: 1.3305 - val_acc: 0.3986
#
# Epoch 00029: val_acc did not improve from 0.43357
# Epoch 30/100
# 1146/1146 [==============================] - 1s 828us/step - loss: 1.1780 - acc: 0.4843 - val_loss: 1.3310 - val_acc: 0.3846
#
# Epoch 00030: val_acc did not improve from 0.43357
# Epoch 31/100
# 1146/1146 [==============================] - 1s 798us/step - loss: 1.1488 - acc: 0.5079 - val_loss: 1.3221 - val_acc: 0.4056
#
# Epoch 00031: val_acc did not improve from 0.43357
# Epoch 32/100
# 1146/1146 [==============================] - 1s 836us/step - loss: 1.1474 - acc: 0.5131 - val_loss: 1.3322 - val_acc: 0.3881
#
# Epoch 00032: val_acc did not improve from 0.43357
# Epoch 33/100
# 1146/1146 [==============================] - 1s 797us/step - loss: 1.1504 - acc: 0.5262 - val_loss: 1.3477 - val_acc: 0.3951
#
# Epoch 00033: val_acc did not improve from 0.43357
# Epoch 34/100
# 1146/1146 [==============================] - 1s 795us/step - loss: 1.1395 - acc: 0.5079 - val_loss: 1.3471 - val_acc: 0.4021
#
# Epoch 00034: val_acc did not improve from 0.43357
# Epoch 35/100
# 1146/1146 [==============================] - 1s 825us/step - loss: 1.1453 - acc: 0.5052 - val_loss: 1.3311 - val_acc: 0.3811
#
# Epoch 00035: val_acc did not improve from 0.43357
# Epoch 36/100
# 1146/1146 [==============================] - 1s 826us/step - loss: 1.1255 - acc: 0.5131 - val_loss: 1.3479 - val_acc: 0.4091
#
# Epoch 00036: val_acc did not improve from 0.43357
# Epoch 37/100
# 1146/1146 [==============================] - 1s 807us/step - loss: 1.1382 - acc: 0.5148 - val_loss: 1.3426 - val_acc: 0.3601
#
# Epoch 00037: val_acc did not improve from 0.43357
# Epoch 38/100
# 1146/1146 [==============================] - 1s 814us/step - loss: 1.1194 - acc: 0.5218 - val_loss: 1.3806 - val_acc: 0.3636
#
# Epoch 00038: val_acc did not improve from 0.43357
# Epoch 39/100
# 1146/1146 [==============================] - 1s 816us/step - loss: 1.1237 - acc: 0.5113 - val_loss: 1.3365 - val_acc: 0.4161
#
# Epoch 00039: val_acc did not improve from 0.43357
# Epoch 40/100
# 1146/1146 [==============================] - 1s 826us/step - loss: 1.1099 - acc: 0.5288 - val_loss: 1.3456 - val_acc: 0.3706
# Epoch 00040: val_acc did not improve from 0.43357
# Epoch 41/100
# 1146/1146 [==============================] - 1s 807us/step - loss: 1.1184 - acc: 0.5288 - val_loss: 1.3527 - val_acc: 0.3986
#
# Epoch 00041: val_acc did not improve from 0.43357
# Epoch 42/100
# 1146/1146 [==============================] - 1s 819us/step - loss: 1.0986 - acc: 0.5305 - val_loss: 1.3335 - val_acc: 0.4021
#
# Epoch 00042: val_acc did not improve from 0.43357
# Epoch 43/100
# 1146/1146 [==============================] - 1s 800us/step - loss: 1.1058 - acc: 0.5358 - val_loss: 1.3346 - val_acc: 0.3741
#
# Epoch 00043: val_acc did not improve from 0.43357
# Epoch 44/100
# 1146/1146 [==============================] - 1s 813us/step - loss: 1.0779 - acc: 0.5358 - val_loss: 1.3339 - val_acc: 0.4091
#
# Epoch 00044: val_acc did not improve from 0.43357
# Epoch 45/100
# 1146/1146 [==============================] - 1s 814us/step - loss: 1.0811 - acc: 0.5358 - val_loss: 1.3653 - val_acc: 0.3846
#
# Epoch 00045: val_acc did not improve from 0.43357
# Epoch 46/100
# 1146/1146 [==============================] - 1s 813us/step - loss: 1.0676 - acc: 0.5620 - val_loss: 1.3199 - val_acc: 0.4091
#
# Epoch 00046: val_acc did not improve from 0.43357
# Epoch 47/100
# 1146/1146 [==============================] - 1s 798us/step - loss: 1.0824 - acc: 0.5366 - val_loss: 1.3728 - val_acc: 0.4021
#
# Epoch 00047: val_acc did not improve from 0.43357
# Epoch 48/100
# 1146/1146 [==============================] - 1s 807us/step - loss: 1.0600 - acc: 0.5567 - val_loss: 1.3549 - val_acc: 0.4056
#
# Epoch 00048: val_acc did not improve from 0.43357
# Epoch 49/100
# 1146/1146 [==============================] - 1s 813us/step - loss: 1.0589 - acc: 0.5366 - val_loss: 1.3362 - val_acc: 0.3881
#
# Epoch 00049: val_acc did not improve from 0.43357
# Epoch 50/100
# 1146/1146 [==============================] - 1s 825us/step - loss: 1.0541 - acc: 0.5716 - val_loss: 1.3611 - val_acc: 0.4091
#
# Epoch 00050: val_acc did not improve from 0.43357
# Epoch 51/100
# 1146/1146 [==============================] - 1s 814us/step - loss: 1.0473 - acc: 0.5672 - val_loss: 1.3791 - val_acc: 0.4371
#
# Epoch 00051: val_acc improved from 0.43357 to 0.43706, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 52/100
# 1146/1146 [==============================] - 1s 819us/step - loss: 1.0357 - acc: 0.5672 - val_loss: 1.3487 - val_acc: 0.4126
#
# Epoch 00052: val_acc did not improve from 0.43706
# Epoch 53/100
# 1146/1146 [==============================] - 1s 838us/step - loss: 1.0504 - acc: 0.5497 - val_loss: 1.4016 - val_acc: 0.3986
#
# Epoch 00053: val_acc did not improve from 0.43706
# Epoch 54/100
# 1146/1146 [==============================] - 1s 804us/step - loss: 1.0434 - acc: 0.5585 - val_loss: 1.3695 - val_acc: 0.3951
#
# Epoch 00054: val_acc did not improve from 0.43706
# Epoch 55/100
# 1146/1146 [==============================] - 1s 790us/step - loss: 1.0156 - acc: 0.5724 - val_loss: 1.3941 - val_acc: 0.4056
#
# Epoch 00055: val_acc did not improve from 0.43706
# Epoch 56/100
# 1146/1146 [==============================] - 1s 797us/step - loss: 1.0387 - acc: 0.5462 - val_loss: 1.3800 - val_acc: 0.4231
#
# Epoch 00056: val_acc did not improve from 0.43706
# Epoch 57/100
# 1146/1146 [==============================] - 1s 819us/step - loss: 1.0134 - acc: 0.5934 - val_loss: 1.3926 - val_acc: 0.4021
#
# Epoch 00057: val_acc did not improve from 0.43706
# Epoch 58/100
# 1146/1146 [==============================] - 1s 799us/step - loss: 1.0214 - acc: 0.5646 - val_loss: 1.3802 - val_acc: 0.4266
#
# Epoch 00058: val_acc did not improve from 0.43706
# Epoch 59/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 1.0160 - acc: 0.5855 - val_loss: 1.3571 - val_acc: 0.4231
#
# Epoch 00059: val_acc did not improve from 0.43706
# Epoch 60/100
# 1146/1146 [==============================] - 1s 815us/step - loss: 0.9968 - acc: 0.5768 - val_loss: 1.4051 - val_acc: 0.4371
#
# Epoch 00060: val_acc did not improve from 0.43706
# Epoch 61/100
# 1146/1146 [==============================] - 1s 823us/step - loss: 0.9872 - acc: 0.5820 - val_loss: 1.3826 - val_acc: 0.4371
#
# Epoch 00061: val_acc did not improve from 0.43706
# Epoch 62/100
# 1146/1146 [==============================] - 1s 814us/step - loss: 0.9880 - acc: 0.5881 - val_loss: 1.4443 - val_acc: 0.4371
#
# Epoch 00062: val_acc did not improve from 0.43706
# Epoch 63/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 0.9795 - acc: 0.5846 - val_loss: 1.4265 - val_acc: 0.4196
#
# Epoch 00063: val_acc did not improve from 0.43706
# Epoch 64/100
# 1146/1146 [==============================] - 1s 837us/step - loss: 0.9898 - acc: 0.5881 - val_loss: 1.4297 - val_acc: 0.4266
#
# Epoch 00064: val_acc did not improve from 0.43706
# Epoch 65/100
# 1146/1146 [==============================] - 1s 826us/step - loss: 0.9851 - acc: 0.5829 - val_loss: 1.4302 - val_acc: 0.4161
#
# Epoch 00065: val_acc did not improve from 0.43706
# Epoch 66/100
# 1146/1146 [==============================] - 1s 801us/step - loss: 0.9570 - acc: 0.6056 - val_loss: 1.4842 - val_acc: 0.4126
#
# Epoch 00066: val_acc did not improve from 0.43706
# Epoch 67/100
# 1146/1146 [==============================] - 1s 812us/step - loss: 0.9476 - acc: 0.6187 - val_loss: 1.4452 - val_acc: 0.4091
#
# Epoch 00067: val_acc did not improve from 0.43706
# Epoch 68/100
# 1146/1146 [==============================] - 1s 812us/step - loss: 0.9540 - acc: 0.6152 - val_loss: 1.3840 - val_acc: 0.4056
#
# Epoch 00068: val_acc did not improve from 0.43706
# Epoch 69/100
# 1146/1146 [==============================] - 1s 810us/step - loss: 0.9372 - acc: 0.6047 - val_loss: 1.5054 - val_acc: 0.3916
#
# Epoch 00069: val_acc did not improve from 0.43706
# Epoch 70/100
# 1146/1146 [==============================] - 1s 816us/step - loss: 0.9165 - acc: 0.6187 - val_loss: 1.4859 - val_acc: 0.4266
#
# Epoch 00070: val_acc did not improve from 0.43706
# Epoch 71/100
# 1146/1146 [==============================] - 1s 817us/step - loss: 0.9507 - acc: 0.5899 - val_loss: 1.4352 - val_acc: 0.4301
#
# Epoch 00071: val_acc did not improve from 0.43706
# Epoch 72/100
# 1146/1146 [==============================] - 1s 815us/step - loss: 0.9357 - acc: 0.6222 - val_loss: 1.4657 - val_acc: 0.4196
#
# Epoch 00072: val_acc did not improve from 0.43706
# Epoch 73/100
# 1146/1146 [==============================] - 1s 796us/step - loss: 0.8940 - acc: 0.6265 - val_loss: 1.4951 - val_acc: 0.3986
#
# Epoch 00073: val_acc did not improve from 0.43706
# Epoch 74/100
# 1146/1146 [==============================] - 1s 829us/step - loss: 0.8810 - acc: 0.6510 - val_loss: 1.5088 - val_acc: 0.3881
#
# Epoch 00074: val_acc did not improve from 0.43706
# Epoch 75/100
# 1146/1146 [==============================] - 1s 807us/step - loss: 0.9077 - acc: 0.6361 - val_loss: 1.5418 - val_acc: 0.4161
#
# Epoch 00075: val_acc did not improve from 0.43706
# Epoch 76/100
# 1146/1146 [==============================] - 1s 815us/step - loss: 0.8899 - acc: 0.6291 - val_loss: 1.5753 - val_acc: 0.4196
#
# Epoch 00076: val_acc did not improve from 0.43706
# Epoch 77/100
# 1146/1146 [==============================] - 1s 816us/step - loss: 0.8812 - acc: 0.6353 - val_loss: 1.4909 - val_acc: 0.4301
#
# Epoch 00077: val_acc did not improve from 0.43706
# Epoch 78/100
# 1146/1146 [==============================] - 1s 810us/step - loss: 0.8686 - acc: 0.6405 - val_loss: 1.5112 - val_acc: 0.4406
#
# Epoch 00078: val_acc improved from 0.43706 to 0.44056, saving model to CNNLSTM-ROLL-ATTENTION-ROLL-BF-SPLIT-energie.h5
# Epoch 79/100
# 1146/1146 [==============================] - 1s 797us/step - loss: 0.8728 - acc: 0.6405 - val_loss: 1.6028 - val_acc: 0.3916
#
# Epoch 00079: val_acc did not improve from 0.44056
# Epoch 80/100
# 1146/1146 [==============================] - 1s 805us/step - loss: 0.8556 - acc: 0.6597 - val_loss: 1.6093 - val_acc: 0.3846
#
# Epoch 00080: val_acc did not improve from 0.44056
# Epoch 81/100
# 1146/1146 [==============================] - 1s 785us/step - loss: 0.8353 - acc: 0.6571 - val_loss: 1.5947 - val_acc: 0.3811
#
# Epoch 00081: val_acc did not improve from 0.44056
# Epoch 82/100
# 1146/1146 [==============================] - 1s 810us/step - loss: 0.8389 - acc: 0.6545 - val_loss: 1.5898 - val_acc: 0.4021
#
# Epoch 00082: val_acc did not improve from 0.44056
# Epoch 83/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 0.8294 - acc: 0.6623 - val_loss: 1.6067 - val_acc: 0.3951
#
# Epoch 00083: val_acc did not improve from 0.44056
# Epoch 84/100
# 1146/1146 [==============================] - 1s 805us/step - loss: 0.8288 - acc: 0.6510 - val_loss: 1.6230 - val_acc: 0.3881
#
# Epoch 00084: val_acc did not improve from 0.44056
# Epoch 85/100
# 1146/1146 [==============================] - 1s 813us/step - loss: 0.8220 - acc: 0.6553 - val_loss: 1.5644 - val_acc: 0.4161
#
# Epoch 00085: val_acc did not improve from 0.44056
# Epoch 86/100
# 1146/1146 [==============================] - 1s 822us/step - loss: 0.7925 - acc: 0.6736 - val_loss: 1.7068 - val_acc: 0.3846
#
# Epoch 00086: val_acc did not improve from 0.44056
# Epoch 87/100
# 1146/1146 [==============================] - 1s 800us/step - loss: 0.7786 - acc: 0.6815 - val_loss: 1.6297 - val_acc: 0.4056
#
# Epoch 00087: val_acc did not improve from 0.44056
# Epoch 88/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 0.7787 - acc: 0.6894 - val_loss: 1.7706 - val_acc: 0.3951
#
# Epoch 00088: val_acc did not improve from 0.44056
# Epoch 89/100
# 1146/1146 [==============================] - 1s 833us/step - loss: 0.8222 - acc: 0.6684 - val_loss: 1.6289 - val_acc: 0.3986
#
# Epoch 00089: val_acc did not improve from 0.44056
# Epoch 90/100
# 1146/1146 [==============================] - 1s 808us/step - loss: 0.7400 - acc: 0.6946 - val_loss: 1.6884 - val_acc: 0.4126
#
# Epoch 00090: val_acc did not improve from 0.44056
# Epoch 91/100
# 1146/1146 [==============================] - 1s 804us/step - loss: 0.7557 - acc: 0.6850 - val_loss: 1.7732 - val_acc: 0.3986
#
# Epoch 00091: val_acc did not improve from 0.44056
# Epoch 92/100
# 1146/1146 [==============================] - 1s 824us/step - loss: 0.7890 - acc: 0.6850 - val_loss: 1.6596 - val_acc: 0.4161
#
# Epoch 00092: val_acc did not improve from 0.44056
# Epoch 93/100
# 1146/1146 [==============================] - 1s 818us/step - loss: 0.7275 - acc: 0.6998 - val_loss: 1.7187 - val_acc: 0.3951
#
# Epoch 00093: val_acc did not improve from 0.44056
# Epoch 94/100
# 1146/1146 [==============================] - 1s 825us/step - loss: 0.7421 - acc: 0.6955 - val_loss: 1.7163 - val_acc: 0.4266
#
# Epoch 00094: val_acc did not improve from 0.44056
# Epoch 95/100
# 1146/1146 [==============================] - 1s 792us/step - loss: 0.7067 - acc: 0.7243 - val_loss: 1.7525 - val_acc: 0.3986
#
# Epoch 00095: val_acc did not improve from 0.44056
# Epoch 96/100
# 1146/1146 [==============================] - 1s 830us/step - loss: 0.7226 - acc: 0.6990 - val_loss: 1.7389 - val_acc: 0.4056
#
# Epoch 00096: val_acc did not improve from 0.44056
# Epoch 97/100
# 1146/1146 [==============================] - 1s 833us/step - loss: 0.7288 - acc: 0.7164 - val_loss: 1.7808 - val_acc: 0.4021
#
# Epoch 00097: val_acc did not improve from 0.44056
# Epoch 98/100
# 1146/1146 [==============================] - 1s 807us/step - loss: 0.7111 - acc: 0.7147 - val_loss: 1.7857 - val_acc: 0.4021
#
# Epoch 00098: val_acc did not improve from 0.44056
# Epoch 99/100
# 1146/1146 [==============================] - 1s 818us/step - loss: 0.6880 - acc: 0.7339 - val_loss: 1.8188 - val_acc: 0.3951
#
# Epoch 00099: val_acc did not improve from 0.44056
# Epoch 100/100
# 1146/1146 [==============================] - 1s 794us/step - loss: 0.6778 - acc: 0.7260 - val_loss: 1.8236 - val_acc: 0.3986
#
# Epoch 00100: val_acc did not improve from 0.44056

# %%
import json,codecs
import numpy as np
def saveHist(path,history):

    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           if  type(history.history[key][0]) == np.float64:
               new_hist[key] = list(map(float, history.history[key]))

    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 

def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n


saveHist('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.hist',history)
hist=loadHist('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.hist')

# %%
import matplotlib.pylab as plt

acc=np.array(hist['acc'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_acc'],'b',label='CNNLSTM')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import load_model
model = load_model('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5',custom_objects={'CylindricalPadLSTMCNN':CylindricalPadLSTMCNN})

# %%
from sklearn.metrics import classification_report, confusion_matrix


print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# [[89 22  1  2  1]
#  [52 59 20  6  3]
#  [22 56 44 14  5]
#  [10 44 17 30  7]
#  [ 7 17 12 22 11]]
# Dados Validação acc: 40.66%
#              precision    recall  f1-score   support
#
#           0     0.4944    0.7739    0.6034       115
#           1     0.2980    0.4214    0.3491       140
#           2     0.4681    0.3121    0.3745       141
#           3     0.4054    0.2778    0.3297       108
#           4     0.4074    0.1594    0.2292        69
#
# avg / total     0.4127    0.4066    0.3883       573

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-BF-enegie.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(10,10))
