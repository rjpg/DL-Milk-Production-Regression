# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, Conv3D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.engine.topology import Layer,InputSpec
from keras.layers import ConvLSTM2D
from keras.layers import Input, Permute,  Reshape,  Lambda, Concatenate
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import merge, Multiply

K.set_image_dim_ordering("th")

class CylindricalPadLSTMCNN(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadLSTMCNN, self).__init__(**kwargs)
        self.n = n
        self.m = m
        assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadLSTMCNN, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,:,testElement.shape[4]-self.n:testElement.shape[4]]
        result=tf.concat([testElement,firstColumns], axis=4)
        result=tf.concat([lastColumns,result], axis=4)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,:,0:self.m,:]
            
            y = tf.fill(tf.shape(firstRows), 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=3)
            result=tf.concat([result,y], axis=3)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadLSTMCNN, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

class CylindricalPad(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPad, self).__init__(**kwargs)
        self.n = n
        self.m = m
        #assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPad, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    #input_shape[2] + 2*self.m,
                    # ONLY ADD m 0's to the left for casusal padding
                    input_shape[2] + self.m,
                    input_shape[3] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
        result=tf.concat([testElement,firstColumns], axis=3)
        result=tf.concat([lastColumns,result], axis=3)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,0:self.m,:]
            
            #y = tf.fill(tf.shape(firstRows), 0.)
            sa=tf.shape(firstRows)[0]
            sb=tf.shape(firstRows)[1]
            sc=self.m
            sd=tf.shape(firstRows)[3]
            y = tf.fill([sa, sb,sc, sd], 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=2)
            
            ########## only add 0's to de left for casusal pading
            #############result=tf.concat([result,y], axis=2)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPad, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
print("CylindricalPad class layer defined")

def attention_3d_block(inputs,timesteps):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    time_steps=timesteps
    print("input shape ",inputs.shape)
    print(input_dim)
    #print(time_steps)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    
    #a_probs=(inputs)
    
    #a_probs = Permute((2, 1))(inputs)
    #a_probs = K.transpose(inputs,(0,2,1,3,4))
    #a_probs = K.permute_dimensions(inputs,(0,2,1,3,4))
    
    #print("after permute a_probs shape ",a_probs.shape)
    #a_probs=CylindricalPadLSTMCNN(m=0,n=1)(a_probs)
    
    #a_probs = Conv3D(time_steps,(1,1,3),strides=1,padding='valid',activation='softmax')(a_probs)
    
    #a_probs = Conv3D(time_steps,(1,1,3),strides=1,padding='valid',activation='softmax')(a_probs)
    
    #print("after conv a_probs shape ",a_probs.shape)
    
    varsVec=[]
    for x in range(0,inputs.shape[4]):
            var=Lambda(lambda element : element[:,:,:,:,x])(inputs)
            #var=contxt_padded = Lambda(lambda x: K.expand_dims(x,1))(var)
            #var=K.expand_dims(var, 2)
            print("inside")
            print(var.shape)
            var = Permute((2, 3, 1))(var)
            #var = var[:,:,np.newaxis]
            #var = Conv1D(filters=5 ,kernel_size=5,strides=1,padding='same',name='conv1_%d' % x)(var)
            var = CylindricalPad(m=2,n=1)(var)
            var = Conv2D(filters=5 ,kernel_size=(4,3),strides=1,padding='same',name='conv2_%d' % x)(var)
            var = Conv2D(filters=1 ,kernel_size=(3,2),strides=1,padding='same',activation='softmax',name='conv_final_softmax_%d' % x)(var)
            var = Permute((3, 1,2))(var)
            var=contxt_padded = Lambda(lambda x: K.expand_dims(x,4))(var)
            varsVec.append(var)
    
    #merged = varsVec
    merged = concatenate(varsVec)
    print(merged.shape)
    
    
    #a = Permute((2, 1))(inputs)
    #a_probs = Conv1D(input_dim,3,strides=1,padding='same',activation='softmax')(inputs)
    #a = Reshape((-1,input_dim, time_steps))(a) # this line is not useful. It's just to know which dimension is what.
    #a = Conv2D(100,3,padding='same')(a)
    #neurVec=[]
    #for x in range(0,100):
    #    filterImg=Lambda(lambda element : element[:,x,:,:])(a)
    #    flatImg = Flatten()(filterImg)
    #    output = Dense(1, activation='sigmoid')(flatImg)
    #    neurVec.append(output)
    
    #a = concatenate(neurVec)
    #a_probs = Dense(100, activation='softmax')(a)
    #a = Reshape((input_dim, time_steps))(a)
    #a_probs =  K.permute_dimensions(a_probs,(0,2,1,3,4)) #, name='attention_vec ' % (depth)
    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul= Multiply()([inputs, merged]) #name='attention_mul'
    return output_attention_mul


class CNNLSTMROLL:
    @staticmethod
    def build(timeSteps,rows, cols,classes):
        
        inputNet = Input(shape=(timeSteps,1,rows, cols)) #batch_shape=(20, 7, 5) 
        cyPad1=CylindricalPadLSTMCNN(m=0,n=3)(inputNet)
        convlstm2d=ConvLSTM2D(10, kernel_size=(2,7), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=True)(cyPad1)
        #Bidirectional(              ,merge_mode='concat')
        #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
        #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
        attention_mul = attention_3d_block(convlstm2d,timeSteps)
        cyPad2=CylindricalPadLSTMCNN(m=0,n=3)(attention_mul)
        convlstm2d=ConvLSTM2D(20, kernel_size=(2,7), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=False)(cyPad2)
        flat = Flatten()(convlstm2d)
        
        #flat=Flatten()(convlstm2d)

        classificationLayer=Dense(classes)(flat)
        classificationLayer=Activation("softmax")(classificationLayer)
        
        #classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
# Out:
# CylindricalPad class layer defined

# %%
# load data
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cross_validation import train_test_split

def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test

# load all data
#dfin = pd.read_csv('windows-size72-step12.csv',header=None)  #inputs 72 lines per sample
#dfout = pd.read_csv('out-class-size72-step12.csv',header=None)  #output classes 
dfin = pd.read_csv('windows-size168-step12.csv',header=None)  #inputs 72 lines per sample
dfout = pd.read_csv('out-class-size168-step12.csv',header=None)  #output classes 

total_inputs,total_output = dfin.as_matrix().astype(np.float32),dfout.as_matrix().astype(np.int32)

# normalize
scaler = MinMaxScaler(feature_range=(0, 1))
total_inputs = scaler.fit_transform(total_inputs)

# every 72 lines is one input sample
total_inputs = np.reshape(total_inputs, (-1,168,8))
total_inputs = np.reshape(total_inputs, (-1,7,24,8))

print("############# total shapes #############")
print(total_inputs.shape)
print(total_output.size)

train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)
print("############# train shapes #############")
print(train_inputs.shape)
print(train_output.shape)

print("############# test shapes #############")
print(test_inputs.shape)
print(test_output.shape)
# Out:
# ############# total shapes #############
# (2868, 7, 24, 8)
# 2868
# ############# train shapes #############
# (2295, 7, 24, 8)
# (2295, 1)
# ############# test shapes #############
# (573, 7, 24, 8)
# (573, 1)
# /home/rjpg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
IMG_ROWS, IMG_COLS = 72, 8 # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes

X_train = train_inputs[:,:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:,:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)
print(y_test.shape)

OPTIMIZER = Adam()

model = CNNLSTMROLL.build(timeSteps=7,rows=24, cols=8,classes=5)
model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
	metrics=["accuracy"])

model.summary()
# Out:
# (573, 5)
# input shape  (?, ?, 10, 23, 8)
# 10
# inside
# (?, ?, 10, 23)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     454                 preferred_dtype=default_dtype,
# --> 455                 as_ref=input_arg.is_ref)
#     456             if input_arg.number_attr and len(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_n_to_tensor(values, dtype, name, as_ref, preferred_dtype, ctx)
#    1171             preferred_dtype=preferred_dtype,
# -> 1172             ctx=ctx))
#    1173   return ret
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1106     if ret is None:
# -> 1107       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1108
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _dimension_tensor_conversion_function(d, dtype, name, as_ref)
#     269   if d.value is None:
# --> 270     raise ValueError("Cannot convert an unknown Dimension to a Tensor: %s" % d)
#     271   if dtype is not None:
#
# ValueError: Cannot convert an unknown Dimension to a Tensor: ?
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-64cd070aeb91> in <module>()
#      11 OPTIMIZER = Adam()
#      12
# ---> 13 model = CNNLSTMROLL.build(timeSteps=7,rows=24, cols=8,classes=5)
#      14 model.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
#      15 	metrics=["accuracy"])
#
# <ipython-input-46-b93228765614> in build(timeSteps, rows, cols, classes)
#     226         #convlstm2d=CylindricalPadLSTMCNN(m=0,n=1)(convlstm2d)
#     227         #convlstm2d=ConvLSTM2D(10, kernel_size=(2,3), padding="valid", dropout=0.2, recurrent_dropout=0.1)(convlstm2d)
# --> 228         attention_mul = attention_3d_block(convlstm2d,timeSteps)
#     229         cyPad2=CylindricalPadLSTMCNN(m=0,n=3)(attention_mul)
#     230         convlstm2d=ConvLSTM2D(20, kernel_size=(2,7), padding="valid", dropout=0.25, recurrent_dropout=0.15,return_sequences=False)(cyPad2)
#
# <ipython-input-46-b93228765614> in attention_3d_block(inputs, timesteps)
#     184             #var = var[:,:,np.newaxis]
#     185             #var = Conv1D(filters=5 ,kernel_size=5,strides=1,padding='same',name='conv1_%d' % x)(var)
# --> 186             var = CylindricalPad(m=2,n=1)(var)
#     187             var = Conv2D(filters=5 ,kernel_size=(4,3),strides=1,padding='same',name='conv2_%d' % x)(var)
#     188             var = Conv2D(filters=1 ,kernel_size=(3,2),strides=1,padding='same',activation='softmax',name='conv_final_softmax_%d' % x)(var)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     458             # Actually call the layer,
#     459             # collecting output(s), mask(s), and shape(s).
# --> 460             output = self.call(inputs, **kwargs)
#     461             output_mask = self.compute_mask(inputs, previous_mask)
#     462
#
# <ipython-input-46-b93228765614> in call(self, testElement, mask)
#     108     def call(self,testElement, mask=None):
#     109         firstColumns=testElement[:,:,:,0:self.n]
# --> 110         lastColumns=testElement[:,:,:,testElement.shape[3]-self.n:testElement.shape[3]]
#     111         result=tf.concat([testElement,firstColumns], axis=3)
#     112         result=tf.concat([lastColumns,result], axis=3)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     496                       [tensor] + begin + end + strides) as name:
#     497     if begin:
# --> 498       packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
#     499                                                   stack(strides))
#     500       if (packed_begin.dtype == dtypes.int64 or
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in stack(values, axis, name)
#     872                                                       expanded_num_dims))
#     873
# --> 874   return gen_array_ops.pack(values, axis=axis, name=name)
#     875
#     876
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in pack(values, axis, name)
#    4591     axis = _execute.make_int(axis, "axis")
#    4592     _, _, _op = _op_def_lib._apply_op_helper(
# -> 4593         "Pack", values=values, axis=axis, name=name)
#    4594     _result = _op.outputs[:]
#    4595     _inputs_flat = _op.inputs
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     481                                 (prefix, dtype.name))
#     482               else:
# --> 483                 raise TypeError("%s that don't all match." % prefix)
#     484             else:
#     485               raise TypeError("%s that are invalid." % prefix)
#
# TypeError: Tensors in list passed to 'values' of 'Pack' Op have types [int32, int32, int32, <NOT CONVERTIBLE TO TENSOR>] that don't all match.

# %%
from IPython.display import SVG,display
from keras.utils.vis_utils import model_to_dot
modelSVG=SVG(model_to_dot(model,show_shapes=True).create(prog='dot', format='svg'))
display(modelSVG)

# %%
NB_EPOCH = 100
BATCH_SIZE = 64
VERBOSE = 1

#tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
#esCallBack = EarlyStopping(monitor='val_acc', min_delta=0, patience=12, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.01,patience=5, min_lr=0.0001)
best_checkpoint = ModelCheckpoint('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie-2.h5', monitor='val_acc', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, 
		batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
		verbose=1, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
		validation_data=(X_test,y_test),
		#validation_split=VALIDATION_SPLIT,
		callbacks=[best_checkpoint])
# Out:
# Train on 2295 samples, validate on 573 samples
# Epoch 1/100
# 2295/2295 [==============================] - 10s 4ms/step - loss: 1.5978 - acc: 0.2340 - val_loss: 1.5771 - val_acc: 0.2373
#
# Epoch 00001: val_acc improved from -inf to 0.23735, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 2/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4879 - acc: 0.3473 - val_loss: 1.4752 - val_acc: 0.3089
#
# Epoch 00002: val_acc improved from 0.23735 to 0.30890, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 3/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4389 - acc: 0.3678 - val_loss: 1.4372 - val_acc: 0.3368
#
# Epoch 00003: val_acc improved from 0.30890 to 0.33682, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 4/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4298 - acc: 0.3647 - val_loss: 1.4499 - val_acc: 0.3194
#
# Epoch 00004: val_acc did not improve from 0.33682
# Epoch 5/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4222 - acc: 0.3721 - val_loss: 1.4380 - val_acc: 0.3264
#
# Epoch 00005: val_acc did not improve from 0.33682
# Epoch 6/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4109 - acc: 0.3878 - val_loss: 1.4224 - val_acc: 0.3438
#
# Epoch 00006: val_acc improved from 0.33682 to 0.34380, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 7/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4072 - acc: 0.3804 - val_loss: 1.4006 - val_acc: 0.3490
#
# Epoch 00007: val_acc improved from 0.34380 to 0.34904, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 8/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3976 - acc: 0.3800 - val_loss: 1.3888 - val_acc: 0.3962
#
# Epoch 00008: val_acc improved from 0.34904 to 0.39616, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 9/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.4022 - acc: 0.3791 - val_loss: 1.4253 - val_acc: 0.3560
#
# Epoch 00009: val_acc did not improve from 0.39616
# Epoch 10/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3823 - acc: 0.3961 - val_loss: 1.3699 - val_acc: 0.3892
#
# Epoch 00010: val_acc did not improve from 0.39616
# Epoch 11/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3833 - acc: 0.3865 - val_loss: 1.3951 - val_acc: 0.3805
#
# Epoch 00011: val_acc did not improve from 0.39616
# Epoch 12/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3771 - acc: 0.3895 - val_loss: 1.4000 - val_acc: 0.3613
#
# Epoch 00012: val_acc did not improve from 0.39616
# Epoch 13/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3674 - acc: 0.4052 - val_loss: 1.3564 - val_acc: 0.3909
#
# Epoch 00013: val_acc did not improve from 0.39616
# Epoch 14/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3526 - acc: 0.4153 - val_loss: 1.4124 - val_acc: 0.3543
#
# Epoch 00014: val_acc did not improve from 0.39616
# Epoch 15/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3526 - acc: 0.4122 - val_loss: 1.3628 - val_acc: 0.3892
#
# Epoch 00015: val_acc did not improve from 0.39616
# Epoch 16/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3491 - acc: 0.4166 - val_loss: 1.3920 - val_acc: 0.3543
#
# Epoch 00016: val_acc did not improve from 0.39616
# Epoch 17/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3471 - acc: 0.4065 - val_loss: 1.3752 - val_acc: 0.3927
#
# Epoch 00017: val_acc did not improve from 0.39616
# Epoch 18/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3469 - acc: 0.4179 - val_loss: 1.3854 - val_acc: 0.3630
#
# Epoch 00018: val_acc did not improve from 0.39616
# Epoch 19/100
# 2295/2295 [==============================] - 3s 2ms/step - loss: 1.3494 - acc: 0.4013 - val_loss: 1.3570 - val_acc: 0.4066
#
# Epoch 00019: val_acc improved from 0.39616 to 0.40663, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 20/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3390 - acc: 0.4166 - val_loss: 1.3626 - val_acc: 0.3979
#
# Epoch 00020: val_acc did not improve from 0.40663
# Epoch 21/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3367 - acc: 0.4118 - val_loss: 1.3604 - val_acc: 0.4014
#
# Epoch 00021: val_acc did not improve from 0.40663
# Epoch 22/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3433 - acc: 0.4192 - val_loss: 1.3721 - val_acc: 0.3735
#
# Epoch 00022: val_acc did not improve from 0.40663
# Epoch 23/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3289 - acc: 0.4174 - val_loss: 1.3705 - val_acc: 0.3892
#
# Epoch 00023: val_acc did not improve from 0.40663
# Epoch 24/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3367 - acc: 0.4209 - val_loss: 1.3782 - val_acc: 0.3874
#
# Epoch 00024: val_acc did not improve from 0.40663
# Epoch 25/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3311 - acc: 0.4179 - val_loss: 1.3780 - val_acc: 0.3892
#
# Epoch 00025: val_acc did not improve from 0.40663
# Epoch 26/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3211 - acc: 0.4270 - val_loss: 1.3785 - val_acc: 0.3857
#
# Epoch 00026: val_acc did not improve from 0.40663
# Epoch 27/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3155 - acc: 0.4200 - val_loss: 1.3781 - val_acc: 0.3717
#
# Epoch 00027: val_acc did not improve from 0.40663
# Epoch 28/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3304 - acc: 0.4261 - val_loss: 1.3526 - val_acc: 0.4136
#
# Epoch 00028: val_acc improved from 0.40663 to 0.41361, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 29/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3288 - acc: 0.4209 - val_loss: 1.3587 - val_acc: 0.3857
#
# Epoch 00029: val_acc did not improve from 0.41361
# Epoch 30/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3197 - acc: 0.4183 - val_loss: 1.3514 - val_acc: 0.3962
#
# Epoch 00030: val_acc did not improve from 0.41361
# Epoch 31/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3126 - acc: 0.4362 - val_loss: 1.3477 - val_acc: 0.4136
#
# Epoch 00031: val_acc did not improve from 0.41361
# Epoch 32/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3114 - acc: 0.4309 - val_loss: 1.3694 - val_acc: 0.3892
#
# Epoch 00032: val_acc did not improve from 0.41361
# Epoch 33/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3139 - acc: 0.4187 - val_loss: 1.3501 - val_acc: 0.4084
#
# Epoch 00033: val_acc did not improve from 0.41361
# Epoch 34/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3078 - acc: 0.4336 - val_loss: 1.3902 - val_acc: 0.4031
#
# Epoch 00034: val_acc did not improve from 0.41361
# Epoch 35/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3049 - acc: 0.4244 - val_loss: 1.3585 - val_acc: 0.4101
#
# Epoch 00035: val_acc did not improve from 0.41361
# Epoch 36/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3121 - acc: 0.4344 - val_loss: 1.3460 - val_acc: 0.3962
#
# Epoch 00036: val_acc did not improve from 0.41361
# Epoch 37/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3022 - acc: 0.4253 - val_loss: 1.3573 - val_acc: 0.4049
#
# Epoch 00037: val_acc did not improve from 0.41361
# Epoch 38/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3037 - acc: 0.4344 - val_loss: 1.3916 - val_acc: 0.3839
#
# Epoch 00038: val_acc did not improve from 0.41361
# Epoch 39/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.3001 - acc: 0.4392 - val_loss: 1.3589 - val_acc: 0.3962
#
# Epoch 00039: val_acc did not improve from 0.41361
# Epoch 40/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2887 - acc: 0.4388 - val_loss: 1.4096 - val_acc: 0.3595
#
# Epoch 00040: val_acc did not improve from 0.41361
# Epoch 41/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2881 - acc: 0.4444 - val_loss: 1.3476 - val_acc: 0.4084
#
# Epoch 00041: val_acc did not improve from 0.41361
# Epoch 42/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2864 - acc: 0.4484 - val_loss: 1.3390 - val_acc: 0.4241
#
# Epoch 00042: val_acc improved from 0.41361 to 0.42408, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 43/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2800 - acc: 0.4418 - val_loss: 1.3517 - val_acc: 0.4241
#
# Epoch 00043: val_acc improved from 0.42408 to 0.42408, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 44/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2925 - acc: 0.4431 - val_loss: 1.3728 - val_acc: 0.4049
#
# Epoch 00044: val_acc did not improve from 0.42408
# Epoch 45/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2853 - acc: 0.4462 - val_loss: 1.3658 - val_acc: 0.3787
#
# Epoch 00045: val_acc did not improve from 0.42408
# Epoch 46/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2760 - acc: 0.4423 - val_loss: 1.3792 - val_acc: 0.3979
#
# Epoch 00046: val_acc did not improve from 0.42408
# Epoch 47/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2749 - acc: 0.4566 - val_loss: 1.3476 - val_acc: 0.4066
#
# Epoch 00047: val_acc did not improve from 0.42408
# Epoch 48/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2663 - acc: 0.4623 - val_loss: 1.3474 - val_acc: 0.4049
#
# Epoch 00048: val_acc did not improve from 0.42408
# Epoch 49/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2658 - acc: 0.4510 - val_loss: 1.3548 - val_acc: 0.4066
#
# Epoch 00049: val_acc did not improve from 0.42408
# Epoch 50/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2519 - acc: 0.4606 - val_loss: 1.3864 - val_acc: 0.3927
#
# Epoch 00050: val_acc did not improve from 0.42408
# Epoch 51/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2470 - acc: 0.4654 - val_loss: 1.3620 - val_acc: 0.3979
#
# Epoch 00051: val_acc did not improve from 0.42408
# Epoch 52/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2440 - acc: 0.4675 - val_loss: 1.3546 - val_acc: 0.3997
#
# Epoch 00052: val_acc did not improve from 0.42408
# Epoch 53/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2395 - acc: 0.4684 - val_loss: 1.3740 - val_acc: 0.3857
#
# Epoch 00053: val_acc did not improve from 0.42408
# Epoch 54/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2478 - acc: 0.4654 - val_loss: 1.3422 - val_acc: 0.4171
#
# Epoch 00054: val_acc did not improve from 0.42408
# Epoch 55/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2417 - acc: 0.4623 - val_loss: 1.3563 - val_acc: 0.4119
#
# Epoch 00055: val_acc did not improve from 0.42408
# Epoch 56/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2256 - acc: 0.4710 - val_loss: 1.3490 - val_acc: 0.4119
#
# Epoch 00056: val_acc did not improve from 0.42408
# Epoch 57/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2211 - acc: 0.4810 - val_loss: 1.3514 - val_acc: 0.3927
#
# Epoch 00057: val_acc did not improve from 0.42408
# Epoch 58/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2135 - acc: 0.4810 - val_loss: 1.3550 - val_acc: 0.4293
#
# Epoch 00058: val_acc improved from 0.42408 to 0.42932, saving model to CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5
# Epoch 59/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.2103 - acc: 0.4867 - val_loss: 1.3533 - val_acc: 0.4031
#
# Epoch 00059: val_acc did not improve from 0.42932
# Epoch 60/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1993 - acc: 0.5028 - val_loss: 1.3829 - val_acc: 0.3857
#
# Epoch 00060: val_acc did not improve from 0.42932
# Epoch 61/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1987 - acc: 0.4876 - val_loss: 1.3631 - val_acc: 0.4084
#
# Epoch 00061: val_acc did not improve from 0.42932
# Epoch 62/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1943 - acc: 0.4906 - val_loss: 1.3923 - val_acc: 0.3944
#
# Epoch 00062: val_acc did not improve from 0.42932
# Epoch 63/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1958 - acc: 0.4972 - val_loss: 1.3707 - val_acc: 0.3822
#
# Epoch 00063: val_acc did not improve from 0.42932
# Epoch 64/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1782 - acc: 0.5107 - val_loss: 1.3595 - val_acc: 0.4154
#
# Epoch 00064: val_acc did not improve from 0.42932
# Epoch 65/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1625 - acc: 0.5133 - val_loss: 1.3865 - val_acc: 0.3927
#
# Epoch 00065: val_acc did not improve from 0.42932
# Epoch 66/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1681 - acc: 0.5028 - val_loss: 1.3586 - val_acc: 0.4084
#
# Epoch 00066: val_acc did not improve from 0.42932
# Epoch 67/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1664 - acc: 0.5102 - val_loss: 1.3730 - val_acc: 0.4031
#
# Epoch 00067: val_acc did not improve from 0.42932
# Epoch 68/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1585 - acc: 0.5163 - val_loss: 1.4239 - val_acc: 0.3752
#
# Epoch 00068: val_acc did not improve from 0.42932
# Epoch 69/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1649 - acc: 0.5054 - val_loss: 1.3815 - val_acc: 0.3909
#
# Epoch 00069: val_acc did not improve from 0.42932
# Epoch 70/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1504 - acc: 0.5216 - val_loss: 1.4154 - val_acc: 0.3909
#
# Epoch 00070: val_acc did not improve from 0.42932
# Epoch 71/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1442 - acc: 0.5059 - val_loss: 1.4142 - val_acc: 0.3997
#
# Epoch 00071: val_acc did not improve from 0.42932
# Epoch 72/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1207 - acc: 0.5303 - val_loss: 1.4275 - val_acc: 0.3700
#
# Epoch 00072: val_acc did not improve from 0.42932
# Epoch 73/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1188 - acc: 0.5368 - val_loss: 1.4391 - val_acc: 0.3770
#
# Epoch 00073: val_acc did not improve from 0.42932
# Epoch 74/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.1159 - acc: 0.5429 - val_loss: 1.4142 - val_acc: 0.3962
#
# Epoch 00074: val_acc did not improve from 0.42932
# Epoch 75/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0973 - acc: 0.5407 - val_loss: 1.4222 - val_acc: 0.3944
#
# Epoch 00075: val_acc did not improve from 0.42932
# Epoch 76/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0818 - acc: 0.5560 - val_loss: 1.4351 - val_acc: 0.4066
#
# Epoch 00076: val_acc did not improve from 0.42932
# Epoch 77/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0773 - acc: 0.5503 - val_loss: 1.4366 - val_acc: 0.3927
#
# Epoch 00077: val_acc did not improve from 0.42932
# Epoch 78/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0665 - acc: 0.5617 - val_loss: 1.4758 - val_acc: 0.3839
#
# Epoch 00078: val_acc did not improve from 0.42932
# Epoch 79/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0673 - acc: 0.5617 - val_loss: 1.4610 - val_acc: 0.3787
#
# Epoch 00079: val_acc did not improve from 0.42932
# Epoch 80/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0513 - acc: 0.5747 - val_loss: 1.4397 - val_acc: 0.3909
#
# Epoch 00080: val_acc did not improve from 0.42932
# Epoch 81/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0437 - acc: 0.5717 - val_loss: 1.4679 - val_acc: 0.3892
#
# Epoch 00081: val_acc did not improve from 0.42932
# Epoch 82/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0293 - acc: 0.5808 - val_loss: 1.5149 - val_acc: 0.4136
#
# Epoch 00082: val_acc did not improve from 0.42932
# Epoch 83/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0128 - acc: 0.5882 - val_loss: 1.5014 - val_acc: 0.3962
#
# Epoch 00083: val_acc did not improve from 0.42932
# Epoch 84/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 1.0048 - acc: 0.5913 - val_loss: 1.5095 - val_acc: 0.3735
#
# Epoch 00084: val_acc did not improve from 0.42932
# Epoch 85/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9786 - acc: 0.5991 - val_loss: 1.5356 - val_acc: 0.3717
#
# Epoch 00085: val_acc did not improve from 0.42932
# Epoch 86/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9764 - acc: 0.6009 - val_loss: 1.5290 - val_acc: 0.3717
#
# Epoch 00086: val_acc did not improve from 0.42932
# Epoch 87/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9622 - acc: 0.6148 - val_loss: 1.5302 - val_acc: 0.3735
#
# Epoch 00087: val_acc did not improve from 0.42932
# Epoch 88/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9722 - acc: 0.6074 - val_loss: 1.5749 - val_acc: 0.3735
#
# Epoch 00088: val_acc did not improve from 0.42932
# Epoch 89/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9445 - acc: 0.6166 - val_loss: 1.5731 - val_acc: 0.3770
#
# Epoch 00089: val_acc did not improve from 0.42932
# Epoch 90/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9631 - acc: 0.6048 - val_loss: 1.5733 - val_acc: 0.3787
#
# Epoch 00090: val_acc did not improve from 0.42932
# Epoch 91/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9150 - acc: 0.6362 - val_loss: 1.5404 - val_acc: 0.3822
#
# Epoch 00091: val_acc did not improve from 0.42932
# Epoch 92/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9194 - acc: 0.6336 - val_loss: 1.6155 - val_acc: 0.3717
#
# Epoch 00092: val_acc did not improve from 0.42932
# Epoch 93/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.9027 - acc: 0.6405 - val_loss: 1.6168 - val_acc: 0.3613
#
# Epoch 00093: val_acc did not improve from 0.42932
# Epoch 94/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8866 - acc: 0.6436 - val_loss: 1.6273 - val_acc: 0.3578
#
# Epoch 00094: val_acc did not improve from 0.42932
# Epoch 95/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8874 - acc: 0.6401 - val_loss: 1.6899 - val_acc: 0.3473
#
# Epoch 00095: val_acc did not improve from 0.42932
# Epoch 96/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8696 - acc: 0.6497 - val_loss: 1.6341 - val_acc: 0.3647
#
# Epoch 00096: val_acc did not improve from 0.42932
# Epoch 97/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8532 - acc: 0.6501 - val_loss: 1.6591 - val_acc: 0.3735
#
# Epoch 00097: val_acc did not improve from 0.42932
# Epoch 98/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8329 - acc: 0.6710 - val_loss: 1.7432 - val_acc: 0.3735
#
# Epoch 00098: val_acc did not improve from 0.42932
# Epoch 99/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8245 - acc: 0.6728 - val_loss: 1.6843 - val_acc: 0.3857
#
# Epoch 00099: val_acc did not improve from 0.42932
# Epoch 100/100
# 2295/2295 [==============================] - 3s 1ms/step - loss: 0.8156 - acc: 0.6793 - val_loss: 1.7065 - val_acc: 0.3717
#
# Epoch 00100: val_acc did not improve from 0.42932

# %%
import json,codecs
import numpy as np
def saveHist(path,history):

    new_hist = {}
    for key in list(history.history.keys()):
        if type(history.history[key]) == np.ndarray:
            new_hist[key] == history.history[key].tolist()
        elif type(history.history[key]) == list:
           if  type(history.history[key][0]) == np.float64:
               new_hist[key] = list(map(float, history.history[key]))

    #print(new_hist)
    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(new_hist, f, separators=(',', ':'), sort_keys=True, indent=4) 

def loadHist(path):
    with codecs.open(path, 'r', encoding='utf-8') as f:
        n = json.loads(f.read())
    return n


saveHist('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.hist',history)

# %%
import matplotlib.pylab as plt

hist=loadHist('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.hist')

acc=np.array(hist['acc'])
#acc=acc[0:100]
#acc=np.append(acc,[0.7])
plt.plot(acc,'b--')
plt.plot(hist['val_acc'],'b',label='CNNLSTM')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='upper left')
plt.show()
# summarize history for loss
loss=np.array(hist['loss'])
#loss=np.append(loss,[2])
plt.plot(loss,'b--',label='train')
plt.plot(hist['val_loss'],'b',label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import load_model
model = load_model('CNNLSTM-ROLL-ATTENTION-BF-SPLIT-energie.h5',custom_objects={'CylindricalPadLSTMCNN':CylindricalPadLSTMCNN})

# %%
from sklearn.metrics import classification_report, confusion_matrix


print('Confusion Matrix')
cm=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(model.predict(X_test),axis=1))
print(cm)
scores = model.evaluate(X_test,y_test, verbose=0)
print("Dados Validação %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

pred = model.predict(X_test)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted,digits=4)
print(report)
# Out:
# Confusion Matrix
# [[108   5   0   0   2]
#  [ 96  24  10   8   2]
#  [ 89  26  13  11   2]
#  [ 53  11  15  24   5]
#  [ 48   2   6   6   7]]
# Dados Validação acc: 30.72%
#              precision    recall  f1-score   support
#
#           0     0.2741    0.9391    0.4244       115
#           1     0.3529    0.1714    0.2308       140
#           2     0.2955    0.0922    0.1405       141
#           3     0.4898    0.2222    0.3057       108
#           4     0.3889    0.1014    0.1609        69
#
# avg / total     0.3531    0.3072    0.2531       573

# %%
import seaborn as sns

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig("LSTM-ATTENTION-CONV1D-BF-enegie.pdf")
    plt.show()
    
    
    
cm_analysis(np.argmax(y_test,axis=1),np.argmax(pred,axis=1), labels=["1","2","3","4","5"], ymap=None, figsize=(6,6))
